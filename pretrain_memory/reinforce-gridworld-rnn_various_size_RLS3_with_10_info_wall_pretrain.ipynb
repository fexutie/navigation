# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#quick-start" data-toc-modified-id="quick-start-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>quick start</a></span><ul class="toc-item"><li><span><a href="#Resources" data-toc-modified-id="Resources-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Resources</a></span></li></ul></li><li><span><a href="#FULL-MODEL" data-toc-modified-id="FULL-MODEL-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>FULL MODEL</a></span><ul class="toc-item"><li><span><a href="#Packages" data-toc-modified-id="Packages-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Packages</a></span><ul class="toc-item"><li><span><a href="#Qnetwork" data-toc-modified-id="Qnetwork-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Qnetwork</a></span></li></ul></li><li><span><a href="#POMDP-RNN-Game" data-toc-modified-id="POMDP-RNN-Game-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>POMDP RNN Game</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#Standard-setting：-grid-=--(3,7)，-holes-=-0" data-toc-modified-id="Standard-setting：-grid-=--(3,7)，-holes-=-0-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Standard setting： grid =  (3,7)， holes = 0</a></span></li><li><span><a href="#Model-Tranining" data-toc-modified-id="Model-Tranining-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Model Tranining</a></span></li><li><span><a href="#decoding-vs-performance" data-toc-modified-id="decoding-vs-performance-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>decoding vs performance</a></span></li><li><span><a href="#learning-rate-vs-performance" data-toc-modified-id="learning-rate-vs-performance-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>learning rate vs performance</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#Anlytic-part-,-check-the-behaviour-correspond-to-each-decoding-level-and-explain-why" data-toc-modified-id="Anlytic-part-,-check-the-behaviour-correspond-to-each-decoding-level-and-explain-why-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>Anlytic part , check the behaviour correspond to each decoding level and explain why</a></span></li></ul></li><li><span><a href="#PCA" data-toc-modified-id="PCA-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>PCA</a></span></li></ul></li></ul></div>

# %% [markdown]
# # quick start

# %% [markdown]
# No information on wall, this very nature case which needs the exploration, try to see its relation of generalization to performance
# Pretrain from the full training, but then reduce it to h2h pre

# %% [markdown]
# ## Resources
#
# * [*The* Reinforcement learning book from Sutton & Barto](http://incompleteideas.net/sutton/book/the-book-2nd.html)
# * [The REINFORCE paper from Ronald J. Williams (1992)](http://www-anw.cs.umass.edu/~barto/courses/cs687/williams92simple.pdf)

# %% [markdown]
# ## Packages

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from itertools import count
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
from torch.autograd import Variable
from torch.nn import init
from torch.nn import DataParallel
from torch.utils.data import DataLoader

import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib.animation
import seaborn as sns
from IPython.display import HTML

from collections import OrderedDict


import pretrain
from pretrain import *

import navigation2
from navigation2 import *

# %pylab inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Qnetwork
#
# To select actions we take maximum of Q value, corresponding to certain move.

# %% [markdown]
# For the liquid state approach to work, you need a lot of neurons as surplus or enough hidden to hidden connectivity to make it have an effect.

# %% [markdown]
# ##  POMDP RNN Game
#
# In this game , we use a new reward function determined by game, if the agent achieves the goal before 50, reward is 1. If time pass 50 reward is 0.5, once time pass 100 agent gets a reward of -0.5 .  Practically, this is found to be easier to learn than the rewards as a continous function of time.  Tf the agent learns to search in a efficient way, the largest possible way for search is to firstly arrive at corner then goes to the goal, which, takes about 50 steps, it is reasonble to make 50 and 100 as milestone thing.  Also in principe as the game doesn't have a timer , it is not if it can use a reward as funtion of time

# %% [markdown]
# 3 condition for ending , when pass time limit, game over

# %% [markdown]
# For weight update, it seems to be better do it after episode, as it makes non-sense evaluate strategy during episode, but a the end. Also, it is much quicker.

# %% [markdown]
# A programming of MDP here, hidden state is as state of enviroment

# %% [markdown]
# ## Model Tranining
# Pretranining is done with fixed size 15,  training is between 10 to 15, test on 19

# %% [markdown]
# Training from zero seems to be better because it will allow the agent to explore from new

# %%
2# A complete experiment including pretraining , decoding training, and q learning  
class PretrainTest():
    def __init__(self, weight_write, holes = 0, inputs_type = (0, 0)):
        self.pregame = PretrainGame(grid_size = (15, 15), holes = holes, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)], input_type = inputs_type[0])
        self.game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)], input_type = inputs_type[1])
        self.weight = weight_write
            
    def loadweight(self, weight_load):
#       need to take the state dict as a new dict for updating 
        net_dict = torch.load(weight_load)
        list_modules = [('h2h', net_dict['h2h']), ('a2h', net_dict['a2h']), ('i2h', net_dict['i2h']), ('r2h', net_dict['r2h']), ('bh', net_dict['bh'])]
        select_dict = OrderedDict(list_modules)
        net = self.pregame.net.state_dict()
        net.update(select_dict)
        self.pregame.net.load_state_dict(net)
        torch.save(self.pregame.net.state_dict(), self.weight) 
    
        
    def pretrain(self, trial, weight = None, lr = 1e-5, pretrain = True):  
        # start a pretrained game  
        self.pregame.net.cuda()
        if pretrain == True:
            lr = float(lr)
            if weight != None:
                self.pregame.net.load_state_dict(torch.load(weight))
            self.pregame.fulltrain(lr_rate = lr, trials = int(1e3), batchsize = 4)
        print ('pretrain end', 'module h2h', torch.norm(self.pregame.net.h2h), 'eig real', np.max(self.pregame.net.h2h.eig()[0].cpu().data.numpy()[:,0]),\
                                    'eig img', np.max(self.pregame.net.h2h.eig()[0].cpu().data.numpy()[:,1]))
        if pretrain == True and trial <=10:
            torch.save(self.pregame.net.state_dict(), self.weight[:-1]+'{}'.format(trial))
            
        elif pretrain == True and trial > 10:
            torch.save(self.pregame.net.state_dict(), self.weight[:-2]+'{}'.format(trial))
        elif pretrain == False:
            torch.save(self.pregame.net.state_dict(), self.weight + '{}'.format(trial))
        if pretrain == True and trial <= 10:
            self.weight = self.weight[:-1]+'{}'.format(trial)
        elif pretrain == True and trial > 10:
            self.weight = self.weight[:-2]+'{}'.format(trial)
        elif pretrain == False:
            self.weight = self.weight +'{}'.format(trial)
    
            
    def decode(self, weight = None, size_range = [15], size_test = [15], epsilon = 0):
        if weight != None:
            self.game.net.load_state_dict(torch.load(weight))
        else:
            self.game.net.load_state_dict(torch.load(self.weight))
        rls_q = RLS(1e2)
        rls_sl = RLS(1e2)
        self.game.experiment(rls_q, rls_sl, iterations = 60, epsilon = epsilon, train_hidden = False, train_q = False, size_range = size_range, test = True, decode = True) 
        # tested on size 15
        def precision(size = 15):
            prec0 = np.mean(decodetest(self.game, reward_control= 0, epsilon = epsilon)[0] + decodetest(self.game, reward_control = 1,  epsilon = 0, size = size)[0])
#             prec1 = np.mean(decodetest(self.game, reward_control= 0, epsilon = 0.5)[0] + decodetest(self.game, reward_control =  1,  epsilon = 0.5)[0])
#             prec1 = np.mean(decodetest(self.game, reward_control= 0, epsilon = 1)[0] + decodetest(self.game, reward_control =  1,  epsilon = 1, size = size)[0])
            return prec0
        print ('decode train finish')
        if len(size_test) == 2:
            Prec_s = precision(size = size_test[0])
            Prec_l = precision(size = size_test[1])
            print ('decode end', Prec_s, Prec_l)
            return Prec_s, Prec_l
        elif len(size_test) == 1:
            Prec_s = precision(size = size_test[0])
            print ('decode end', Prec_s)
            return Prec_s
        # q learning session 
    
        
    def qlearn(self, weight_read, weight_write, iterations = 5, save = True,  size_test = [15, 30], train_only = False, test_only = False, noise = 0.3):
        self.pregame.net.load_state_dict(torch.load(weight_read))
        e_rate = [noise for r in range(iterations)] 
        rls_q = RLS(1e2)
        rls_sl = RLS(1e2)
        # q leanring phase
        for n,e in enumerate(e_rate):
            self.game.net.cpu()
            if test_only == False:
                self.game.experiment(rls_q, rls_sl, iterations = 10, epochs= 20, epsilon = e, size_range=(10, 20))    
            if save == True:
                torch.save(self.game.net.state_dict(), weight_write + '_{}'.format(n))
        def testing(game):
            Rewards00 = Test(game, reward_control = 0, size = size_test[0])
            Rewards01 = Test(game, reward_control = 1, size = size_test[0])
            rewards_s = (np.sum(Rewards00) + np.sum(Rewards01))/(2 * self.game.grid_size[0] * self.game.grid_size[1])
            Rewards10 = Test(game, reward_control = 0, size = size_test[1])
            Rewards11 = Test(game, reward_control = 1, size = size_test[1])
            rewards_l = (np.sum(Rewards10) + np.sum(Rewards11))/(2 * self.game.grid_size[0] * self.game.grid_size[1])
            return rewards_s, rewards_l
        # load weight if test only is true 
        if test_only == True:
            self.game.net.load_state_dict(torch.load(weight_write))
        if train_only == False:
            rewards_s, rewards_l = testing(self.game)
        return rewards_s, rewards_l
    
    def TestAllSizes(self, size_range = np.arange(15, 86, 10), limit_set = 8, test_size = None):
        self.game.net.load_state_dict(torch.load(self.weight))
        self.Performance = []
        for size in size_range:
            if test_size == None: 
                test_size = size//25
            else:
                test_size = test_size
            Rewards0 = Test(self.game, reward_control = 0, size = size, test = test_size, limit_set = limit_set)
            Rewards1 = Test(self.game, reward_control = 1, size = size, test = test_size, limit_set = limit_set)
            self.Performance.append((Rewards0 + Rewards1)/2)

# %% [markdown]
# ## Model Train

# %% [markdown]
# **Results can be compared between across different noise level for the initial weights and last 5.  There is a clear trends that training is deproving the generalization performance, but there is actually one exception, the weight 98 is gaining more power to generalize,  the insights is in the next notebook**

# %% [markdown]
# it is easy to intepretate this result,  the pretraining is done for the random walk behaviour , not with real action. But decoding is tested as average of 0, 0.5 1  noise level.  So even the pretraining decrease the random walk decoding error along the way, it has no reason to desend the average in a monotonic manner.   The fact that decoding performance under different noise level converges is showing that dynamics goes nearer and nearer to path integrator.  What is hard to intepretate is actually how dynamics are shaped. why integrator is not associate with a infinit timescale

# %%
# only effect of inverse dynamics with wah = 1  try to find limit cycles 
Precision = []
Pretest =  PretrainTest(weight_write = 'weights{}/rnn_1515tanh512_checkpoint'.format(1), holes = 0)
for i in range(50):
    Pretest.pretrain(i, pretrain = (i!=0), lr = 1e-5)
    Prec = Pretest.decode()
    Precision.append(Prec)
# Out:
# pretrain end module h2h tensor(31.9256, device='cuda:0') eig real 1.39516 eig img 1.37637
# clear session data 59 2563493888
# decode train finish
# decode end 2.6041687549
# loss for epoch: tensor(45072.8359, device='cuda:0')
# loss for epoch: tensor(45059.1172, device='cuda:0')
# loss for epoch: tensor(41696.3633, device='cuda:0')
# loss for epoch: tensor(42651.1719, device='cuda:0')
# loss for epoch: tensor(40972.5625, device='cuda:0')
# loss for epoch: tensor(40099.5664, device='cuda:0')
# loss for epoch: tensor(38078.6133, device='cuda:0')
# loss for epoch: tensor(39040.9375, device='cuda:0')
# loss for epoch: tensor(39469.8984, device='cuda:0')
# loss for epoch: tensor(40048.9805, device='cuda:0')
# loss for epoch: tensor(39355.7461, device='cuda:0')
# loss for epoch: tensor(43026.8555, device='cuda:0')
# loss for epoch: tensor(43252.5820, device='cuda:0')
# loss for epoch: tensor(31909.0801, device='cuda:0')
# loss for epoch: tensor(34753.6055, device='cuda:0')
# loss for epoch: tensor(34841.8945, device='cuda:0')
# loss for epoch: tensor(35718.7969, device='cuda:0')
# loss for epoch: tensor(45825.8047, device='cuda:0')
# loss for epoch: tensor(38284.0938, device='cuda:0')
# pretrain end module h2h tensor(31.7252, device='cuda:0') eig real 1.3151 eig img 1.38976
# clear session data 59 4825202688
# decode train finish
# decode end 2.96736658208
# loss for epoch: tensor(40093.5156, device='cuda:0')
# loss for epoch: tensor(44007.2812, device='cuda:0')
# loss for epoch: tensor(39839.8203, device='cuda:0')
# loss for epoch: tensor(38317.6055, device='cuda:0')
# loss for epoch: tensor(35778.7578, device='cuda:0')
# loss for epoch: tensor(34292.3516, device='cuda:0')
# loss for epoch: tensor(38680.1836, device='cuda:0')
# loss for epoch: tensor(40983.0234, device='cuda:0')
# loss for epoch: tensor(43480.6719, device='cuda:0')
# loss for epoch: tensor(35708.5391, device='cuda:0')
# loss for epoch: tensor(38562.5703, device='cuda:0')
# loss for epoch: tensor(39494.6445, device='cuda:0')
# loss for epoch: tensor(43121.6016, device='cuda:0')
# loss for epoch: tensor(35629.1094, device='cuda:0')
# loss for epoch: tensor(40088.5508, device='cuda:0')
# loss for epoch: tensor(41014.1367, device='cuda:0')
# loss for epoch: tensor(39199.6289, device='cuda:0')
# loss for epoch: tensor(42249.3633, device='cuda:0')
# loss for epoch: tensor(37372.0312, device='cuda:0')
# pretrain end module h2h tensor(31.5595, device='cuda:0') eig real 1.33877 eig img 1.3635
# clear session data 59 4825489408
# decode train finish
# decode end 2.4939096886
# loss for epoch: tensor(39430.6680, device='cuda:0')
# loss for epoch: tensor(40330.0469, device='cuda:0')
# loss for epoch: tensor(42991.7461, device='cuda:0')
# loss for epoch: tensor(40953.2578, device='cuda:0')
# loss for epoch: tensor(40288.4688, device='cuda:0')
# loss for epoch: tensor(43213.8945, device='cuda:0')
# loss for epoch: tensor(42823.5547, device='cuda:0')
# loss for epoch: tensor(38075.8945, device='cuda:0')
# loss for epoch: tensor(37967.5859, device='cuda:0')
# loss for epoch: tensor(36690.7305, device='cuda:0')
# loss for epoch: tensor(39733.4023, device='cuda:0')
# loss for epoch: tensor(46324.6914, device='cuda:0')
# loss for epoch: tensor(42248.9922, device='cuda:0')
# loss for epoch: tensor(36977.2930, device='cuda:0')
# loss for epoch: tensor(41352.1055, device='cuda:0')
# loss for epoch: tensor(41112.1992, device='cuda:0')
# loss for epoch: tensor(39501.9336, device='cuda:0')
# loss for epoch: tensor(32190.9648, device='cuda:0')
# loss for epoch: tensor(33488.5039, device='cuda:0')
# pretrain end module h2h tensor(31.3962, device='cuda:0') eig real 1.35825 eig img 1.36018
# clear session data 59 4850569216
# decode train finish
# decode end 2.07652714262
# loss for epoch: tensor(38960.8203, device='cuda:0')
# loss for epoch: tensor(41897.5039, device='cuda:0')
# loss for epoch: tensor(37783.2500, device='cuda:0')
# loss for epoch: tensor(39323.0820, device='cuda:0')
# loss for epoch: tensor(38425.9102, device='cuda:0')
# loss for epoch: tensor(42755.5000, device='cuda:0')
# loss for epoch: tensor(42034.4375, device='cuda:0')
# loss for epoch: tensor(43514.3711, device='cuda:0')
# loss for epoch: tensor(43149.7344, device='cuda:0')
# loss for epoch: tensor(38084.5664, device='cuda:0')
# loss for epoch: tensor(35438.0938, device='cuda:0')
# loss for epoch: tensor(36522.9297, device='cuda:0')
# loss for epoch: tensor(38448.6953, device='cuda:0')
# loss for epoch: tensor(42572.7031, device='cuda:0')
# loss for epoch: tensor(41207.0703, device='cuda:0')
# loss for epoch: tensor(41804.9453, device='cuda:0')
# loss for epoch: tensor(47586.1719, device='cuda:0')
# loss for epoch: tensor(42422.2734, device='cuda:0')
# loss for epoch: tensor(42482.4570, device='cuda:0')
# pretrain end module h2h tensor(31.2517, device='cuda:0') eig real 1.49804 eig img 1.37492
# clear session data 59 4920635392
# decode train finish
# decode end 2.49678474153
# loss for epoch: tensor(43062.3594, device='cuda:0')
# loss for epoch: tensor(42159.5781, device='cuda:0')
# loss for epoch: tensor(38251.2031, device='cuda:0')
# loss for epoch: tensor(44023.3555, device='cuda:0')
# loss for epoch: tensor(38371.1094, device='cuda:0')
# loss for epoch: tensor(40257.5859, device='cuda:0')
# loss for epoch: tensor(38536.5469, device='cuda:0')
# loss for epoch: tensor(39565.8242, device='cuda:0')
# loss for epoch: tensor(40249.7578, device='cuda:0')
# loss for epoch: tensor(39789.0195, device='cuda:0')
# loss for epoch: tensor(37746.8477, device='cuda:0')
# loss for epoch: tensor(36825.7930, device='cuda:0')
# loss for epoch: tensor(42642.5117, device='cuda:0')
# loss for epoch: tensor(40797.1289, device='cuda:0')
# loss for epoch: tensor(37680.8906, device='cuda:0')
# loss for epoch: tensor(40874.0859, device='cuda:0')
# loss for epoch: tensor(41359.1914, device='cuda:0')
# loss for epoch: tensor(38430.7461, device='cuda:0')
# loss for epoch: tensor(36723.2070, device='cuda:0')
# pretrain end module h2h tensor(31.1065, device='cuda:0') eig real 1.57547 eig img 1.38188
# clear session data 59 4920848384
# decode train finish
# decode end 2.72962667432
# loss for epoch: tensor(38371.5273, device='cuda:0')
# loss for epoch: tensor(39856.8750, device='cuda:0')
# loss for epoch: tensor(42803.0352, device='cuda:0')
# loss for epoch: tensor(43370.6562, device='cuda:0')
# loss for epoch: tensor(37353.7031, device='cuda:0')
# loss for epoch: tensor(39950.1328, device='cuda:0')
# loss for epoch: tensor(39217.0820, device='cuda:0')
# loss for epoch: tensor(38197.7539, device='cuda:0')
# loss for epoch: tensor(42856.7617, device='cuda:0')
# loss for epoch: tensor(34220.2461, device='cuda:0')
# loss for epoch: tensor(37138.4414, device='cuda:0')
# loss for epoch: tensor(35194.1641, device='cuda:0')
# loss for epoch: tensor(40964.0352, device='cuda:0')
# loss for epoch: tensor(37106.2227, device='cuda:0')
# loss for epoch: tensor(43175.1953, device='cuda:0')
# loss for epoch: tensor(37496.3906, device='cuda:0')
# loss for epoch: tensor(37453.4414, device='cuda:0')
# loss for epoch: tensor(36579.6641, device='cuda:0')
# loss for epoch: tensor(43176.6406, device='cuda:0')
# pretrain end module h2h tensor(30.9556, device='cuda:0') eig real 1.51913 eig img 1.38028
# clear session data 59 4923232256
# decode train finish
# decode end 2.75800728605
# loss for epoch: tensor(41807.4102, device='cuda:0')
# loss for epoch: tensor(41058.6250, device='cuda:0')
# loss for epoch: tensor(40594.8711, device='cuda:0')
# loss for epoch: tensor(38908.3945, device='cuda:0')
# loss for epoch: tensor(41333.7930, device='cuda:0')
# loss for epoch: tensor(39685.1758, device='cuda:0')
# loss for epoch: tensor(36127.6406, device='cuda:0')
# loss for epoch: tensor(45245.2461, device='cuda:0')
# loss for epoch: tensor(38773.8828, device='cuda:0')
# loss for epoch: tensor(36650.9883, device='cuda:0')
# loss for epoch: tensor(41888.6914, device='cuda:0')
# loss for epoch: tensor(39313.5000, device='cuda:0')
# loss for epoch: tensor(39511.9570, device='cuda:0')
# loss for epoch: tensor(44172.5039, device='cuda:0')
# loss for epoch: tensor(38703.4648, device='cuda:0')
# loss for epoch: tensor(40001.0859, device='cuda:0')
# loss for epoch: tensor(37489.2891, device='cuda:0')
# loss for epoch: tensor(42170.1562, device='cuda:0')
# loss for epoch: tensor(42380.2891, device='cuda:0')
# pretrain end module h2h tensor(30.8152, device='cuda:0') eig real 1.59698 eig img 1.45357
# clear session data 59 4923240448
# decode train finish
# decode end 3.01610195345
# loss for epoch: tensor(42856.6445, device='cuda:0')
# loss for epoch: tensor(40876.5195, device='cuda:0')
# loss for epoch: tensor(41298.6641, device='cuda:0')
# loss for epoch: tensor(36229.5469, device='cuda:0')
# loss for epoch: tensor(38854.0586, device='cuda:0')
# loss for epoch: tensor(39477.0039, device='cuda:0')
# loss for epoch: tensor(41649.9570, device='cuda:0')
# loss for epoch: tensor(41658.0508, device='cuda:0')
# loss for epoch: tensor(39110.9766, device='cuda:0')
# loss for epoch: tensor(37241.4492, device='cuda:0')
# loss for epoch: tensor(42382.1719, device='cuda:0')
# loss for epoch: tensor(38032.1484, device='cuda:0')
# loss for epoch: tensor(38488.8516, device='cuda:0')
# loss for epoch: tensor(40277.5781, device='cuda:0')
# loss for epoch: tensor(36644.9766, device='cuda:0')
# loss for epoch: tensor(37826.4727, device='cuda:0')
# loss for epoch: tensor(33252.9414, device='cuda:0')
# loss for epoch: tensor(45989.2383, device='cuda:0')
# loss for epoch: tensor(41511.2695, device='cuda:0')
# pretrain end module h2h tensor(30.6913, device='cuda:0') eig real 1.58309 eig img 1.48017
# clear session data 59 4923240448
# decode train finish
# decode end 2.57490029955
# loss for epoch: tensor(41880.5039, device='cuda:0')
# loss for epoch: tensor(41321.2383, device='cuda:0')
# loss for epoch: tensor(40115.1875, device='cuda:0')
# loss for epoch: tensor(36570.6445, device='cuda:0')
# loss for epoch: tensor(43341.7695, device='cuda:0')
# loss for epoch: tensor(40331.4219, device='cuda:0')
# loss for epoch: tensor(42790.3242, device='cuda:0')
# loss for epoch: tensor(36679.0312, device='cuda:0')
# loss for epoch: tensor(39452.3164, device='cuda:0')
# loss for epoch: tensor(36480.1484, device='cuda:0')
# loss for epoch: tensor(37467.8281, device='cuda:0')
# loss for epoch: tensor(43388.6289, device='cuda:0')
# loss for epoch: tensor(44275.3711, device='cuda:0')
# loss for epoch: tensor(38382.8320, device='cuda:0')
# loss for epoch: tensor(39812.6289, device='cuda:0')
# loss for epoch: tensor(34833.8320, device='cuda:0')
# loss for epoch: tensor(34035.4258, device='cuda:0')
# loss for epoch: tensor(40866.6055, device='cuda:0')
# loss for epoch: tensor(39414.1797, device='cuda:0')
# pretrain end module h2h tensor(30.5864, device='cuda:0') eig real 1.58163 eig img 1.47503
# clear session data 59 4923240448
# decode train finish
# decode end 2.80738563364
# loss for epoch: tensor(42034.6680, device='cuda:0')
# loss for epoch: tensor(42918.4570, device='cuda:0')
# loss for epoch: tensor(44865.9102, device='cuda:0')
# loss for epoch: tensor(36527.6406, device='cuda:0')
# loss for epoch: tensor(38036.4883, device='cuda:0')
# loss for epoch: tensor(33518.8438, device='cuda:0')
# loss for epoch: tensor(43618.5000, device='cuda:0')
# loss for epoch: tensor(45430.1094, device='cuda:0')
# loss for epoch: tensor(38860.5352, device='cuda:0')
# loss for epoch: tensor(39950.5625, device='cuda:0')
# loss for epoch: tensor(41441.0586, device='cuda:0')
# loss for epoch: tensor(39320.0547, device='cuda:0')
# loss for epoch: tensor(41494.6758, device='cuda:0')
# loss for epoch: tensor(40010.2930, device='cuda:0')
# loss for epoch: tensor(43108.7578, device='cuda:0')
# loss for epoch: tensor(40331.2422, device='cuda:0')
# loss for epoch: tensor(39743.5078, device='cuda:0')
# loss for epoch: tensor(41790.6445, device='cuda:0')
# loss for epoch: tensor(39925.3477, device='cuda:0')
# pretrain end module h2h tensor(30.4725, device='cuda:0') eig real 1.61375 eig img 1.44869
# clear session data 59 4925128704
# decode train finish
# decode end 2.72326072654
# loss for epoch: tensor(42336.1953, device='cuda:0')
# loss for epoch: tensor(34281.4258, device='cuda:0')
# loss for epoch: tensor(41089.1094, device='cuda:0')
# loss for epoch: tensor(36237.0664, device='cuda:0')
# loss for epoch: tensor(37105.7461, device='cuda:0')
# loss for epoch: tensor(38435.1211, device='cuda:0')
# loss for epoch: tensor(38716.6602, device='cuda:0')
# loss for epoch: tensor(34736.7773, device='cuda:0')
# loss for epoch: tensor(37524.2227, device='cuda:0')
# loss for epoch: tensor(40102.1133, device='cuda:0')
# loss for epoch: tensor(41263.6289, device='cuda:0')
# loss for epoch: tensor(41015.8867, device='cuda:0')
# loss for epoch: tensor(35533.3594, device='cuda:0')
# loss for epoch: tensor(42876.1562, device='cuda:0')
# loss for epoch: tensor(39107.4492, device='cuda:0')
# loss for epoch: tensor(41893.4062, device='cuda:0')
# loss for epoch: tensor(39306.8359, device='cuda:0')
# loss for epoch: tensor(42345.1406, device='cuda:0')
# loss for epoch: tensor(36582.9219, device='cuda:0')
# pretrain end module h2h tensor(30.3700, device='cuda:0') eig real 1.5379 eig img 1.45011
# clear session data 59 4926128128
# decode train finish
# decode end 2.69552074614
# loss for epoch: tensor(41032.7891, device='cuda:0')
# loss for epoch: tensor(34890.6523, device='cuda:0')
# loss for epoch: tensor(41297.6055, device='cuda:0')
# loss for epoch: tensor(33372.3633, device='cuda:0')
# loss for epoch: tensor(35969.5586, device='cuda:0')
# loss for epoch: tensor(41663., device='cuda:0')
# loss for epoch: tensor(40188.3203, device='cuda:0')
# loss for epoch: tensor(41656.9453, device='cuda:0')
# loss for epoch: tensor(43471.7812, device='cuda:0')
# loss for epoch: tensor(39292.2227, device='cuda:0')
# loss for epoch: tensor(36902.2227, device='cuda:0')
# loss for epoch: tensor(38343.3398, device='cuda:0')
# loss for epoch: tensor(36890.9766, device='cuda:0')
# loss for epoch: tensor(36980.9922, device='cuda:0')
# loss for epoch: tensor(38858.5820, device='cuda:0')
# loss for epoch: tensor(41772.2305, device='cuda:0')
# loss for epoch: tensor(38602.1680, device='cuda:0')
# loss for epoch: tensor(35107.2539, device='cuda:0')
# loss for epoch: tensor(40096.8086, device='cuda:0')
# pretrain end module h2h tensor(30.2702, device='cuda:0') eig real 1.58954 eig img 1.4541
# clear session data 59 4926128128
# decode train finish
# decode end 2.63993031354
# loss for epoch: tensor(44196.6562, device='cuda:0')
# loss for epoch: tensor(41931.8672, device='cuda:0')
# loss for epoch: tensor(40916.1836, device='cuda:0')
# loss for epoch: tensor(43641.7695, device='cuda:0')
# loss for epoch: tensor(35687.0469, device='cuda:0')
# loss for epoch: tensor(36046.5586, device='cuda:0')
# loss for epoch: tensor(41473.7070, device='cuda:0')
# loss for epoch: tensor(43268.5781, device='cuda:0')
# loss for epoch: tensor(40131.7891, device='cuda:0')
# loss for epoch: tensor(34070.8555, device='cuda:0')
# loss for epoch: tensor(41465.7344, device='cuda:0')
# loss for epoch: tensor(40977.2109, device='cuda:0')
# loss for epoch: tensor(41033.1797, device='cuda:0')
# loss for epoch: tensor(40821.2148, device='cuda:0')
# loss for epoch: tensor(39237.7695, device='cuda:0')
# loss for epoch: tensor(45435.7969, device='cuda:0')
# loss for epoch: tensor(38586.3594, device='cuda:0')
# loss for epoch: tensor(36360.5469, device='cuda:0')
# loss for epoch: tensor(38567.8633, device='cuda:0')
# pretrain end module h2h tensor(30.1811, device='cuda:0') eig real 1.60923 eig img 1.46885
# clear session data 59 4926128128
# decode train finish
# decode end 2.94814742841
# loss for epoch: tensor(43523.8906, device='cuda:0')
# loss for epoch: tensor(42086.3125, device='cuda:0')
# loss for epoch: tensor(36517.0312, device='cuda:0')
# loss for epoch: tensor(42132.5469, device='cuda:0')
# loss for epoch: tensor(44374.7422, device='cuda:0')
# loss for epoch: tensor(40736.3320, device='cuda:0')
# loss for epoch: tensor(40608.9414, device='cuda:0')
# loss for epoch: tensor(39450.1289, device='cuda:0')
# loss for epoch: tensor(41467.7461, device='cuda:0')
# loss for epoch: tensor(40056.1406, device='cuda:0')
# loss for epoch: tensor(37773.2695, device='cuda:0')
# loss for epoch: tensor(43830.1172, device='cuda:0')
# loss for epoch: tensor(38634.6758, device='cuda:0')
# loss for epoch: tensor(39695.9141, device='cuda:0')
# loss for epoch: tensor(42975.3789, device='cuda:0')
# loss for epoch: tensor(39749.3477, device='cuda:0')
# loss for epoch: tensor(38982.0703, device='cuda:0')
# loss for epoch: tensor(39310.3359, device='cuda:0')
# loss for epoch: tensor(38833.0820, device='cuda:0')
# pretrain end module h2h tensor(30.0927, device='cuda:0') eig real 1.59556 eig img 1.43909
# clear session data 59 4926177280
# decode train finish
# decode end 2.66295024607
# loss for epoch: tensor(41171.6289, device='cuda:0')
# loss for epoch: tensor(41347.7031, device='cuda:0')
# loss for epoch: tensor(38856.7227, device='cuda:0')
# loss for epoch: tensor(37807.8867, device='cuda:0')
# loss for epoch: tensor(44033.0703, device='cuda:0')
# loss for epoch: tensor(34732.4844, device='cuda:0')
# loss for epoch: tensor(38474.0547, device='cuda:0')
# loss for epoch: tensor(43054.3281, device='cuda:0')
# loss for epoch: tensor(40060.3477, device='cuda:0')
# loss for epoch: tensor(37760.7344, device='cuda:0')
# loss for epoch: tensor(43124.1328, device='cuda:0')
# loss for epoch: tensor(40588.3398, device='cuda:0')
# loss for epoch: tensor(42123.4922, device='cuda:0')
# loss for epoch: tensor(36859.7500, device='cuda:0')
# loss for epoch: tensor(40615.5000, device='cuda:0')
# loss for epoch: tensor(40144.1406, device='cuda:0')
# loss for epoch: tensor(36432.1172, device='cuda:0')
# loss for epoch: tensor(41377.8633, device='cuda:0')
# loss for epoch: tensor(42612.4453, device='cuda:0')
# pretrain end module h2h tensor(30.0166, device='cuda:0') eig real 1.64724 eig img 1.42716
# clear session data 59 4926365696
# decode train finish
# decode end 2.68494668812
# loss for epoch: tensor(39421.6523, device='cuda:0')
# loss for epoch: tensor(36656.7539, device='cuda:0')
# loss for epoch: tensor(40515.2500, device='cuda:0')
# loss for epoch: tensor(34404.8438, device='cuda:0')
# loss for epoch: tensor(38787.8008, device='cuda:0')
# loss for epoch: tensor(36157.9531, device='cuda:0')
# loss for epoch: tensor(38701.9492, device='cuda:0')
# loss for epoch: tensor(36332.4453, device='cuda:0')
# loss for epoch: tensor(39516.0547, device='cuda:0')
# loss for epoch: tensor(43424.5273, device='cuda:0')
# loss for epoch: tensor(43700.1094, device='cuda:0')
# loss for epoch: tensor(35520.9883, device='cuda:0')
# loss for epoch: tensor(37583.5352, device='cuda:0')
# loss for epoch: tensor(38710.7695, device='cuda:0')
# loss for epoch: tensor(43640.1211, device='cuda:0')
# loss for epoch: tensor(42315., device='cuda:0')
# loss for epoch: tensor(39512.4766, device='cuda:0')
# loss for epoch: tensor(39930.7031, device='cuda:0')
# loss for epoch: tensor(38707.9336, device='cuda:0')
# pretrain end module h2h tensor(29.9344, device='cuda:0') eig real 1.59735 eig img 1.4344
# clear session data 59 4926365696
# decode train finish
# decode end 2.5893767848
# loss for epoch: tensor(39998.7461, device='cuda:0')
# loss for epoch: tensor(41347.3438, device='cuda:0')
# loss for epoch: tensor(40218.1562, device='cuda:0')
# loss for epoch: tensor(40926.9648, device='cuda:0')
# loss for epoch: tensor(44160.2109, device='cuda:0')
# loss for epoch: tensor(40757.2109, device='cuda:0')
# loss for epoch: tensor(43328.1484, device='cuda:0')
# loss for epoch: tensor(40809.4609, device='cuda:0')
# loss for epoch: tensor(36505.3906, device='cuda:0')
# loss for epoch: tensor(38350.3477, device='cuda:0')
# loss for epoch: tensor(39565.5273, device='cuda:0')
# loss for epoch: tensor(40403.1719, device='cuda:0')
# loss for epoch: tensor(38737.5664, device='cuda:0')
# loss for epoch: tensor(39276.0977, device='cuda:0')
# loss for epoch: tensor(38131.3828, device='cuda:0')
# loss for epoch: tensor(40843.5547, device='cuda:0')
# loss for epoch: tensor(44017.1992, device='cuda:0')
# loss for epoch: tensor(42780.7812, device='cuda:0')
# loss for epoch: tensor(40393.7070, device='cuda:0')
# pretrain end module h2h tensor(29.8573, device='cuda:0') eig real 1.58328 eig img 1.41143
# clear session data 59 4929421312
# decode train finish
# decode end 2.62916628846
# loss for epoch: tensor(38308.0664, device='cuda:0')
# loss for epoch: tensor(40816.6211, device='cuda:0')
# loss for epoch: tensor(46501.8477, device='cuda:0')
# loss for epoch: tensor(38856.1211, device='cuda:0')
# loss for epoch: tensor(37440.8633, device='cuda:0')
# loss for epoch: tensor(42992.2539, device='cuda:0')
# loss for epoch: tensor(37865.0586, device='cuda:0')
# loss for epoch: tensor(40182.9102, device='cuda:0')
# loss for epoch: tensor(40125.2969, device='cuda:0')
# loss for epoch: tensor(41852.6328, device='cuda:0')
# loss for epoch: tensor(38847.0273, device='cuda:0')
# loss for epoch: tensor(41830.6953, device='cuda:0')
# loss for epoch: tensor(42215.4102, device='cuda:0')
# loss for epoch: tensor(43465.0898, device='cuda:0')
# loss for epoch: tensor(37966.1133, device='cuda:0')
# loss for epoch: tensor(41588.0273, device='cuda:0')
# loss for epoch: tensor(35133.7031, device='cuda:0')
# loss for epoch: tensor(38386.2539, device='cuda:0')
# loss for epoch: tensor(43287.7930, device='cuda:0')
# pretrain end module h2h tensor(29.7849, device='cuda:0') eig real 1.58354 eig img 1.43191
# clear session data 59 4929556480
# decode train finish
# decode end 2.64147280188
# loss for epoch: tensor(43355.5312, device='cuda:0')
# loss for epoch: tensor(39899.9414, device='cuda:0')
# loss for epoch: tensor(39042.0312, device='cuda:0')
# loss for epoch: tensor(35305.8789, device='cuda:0')
# loss for epoch: tensor(41247.2539, device='cuda:0')
# loss for epoch: tensor(40467.4570, device='cuda:0')
# loss for epoch: tensor(41235.4766, device='cuda:0')
# loss for epoch: tensor(39020.6875, device='cuda:0')
# loss for epoch: tensor(42516.8438, device='cuda:0')
# loss for epoch: tensor(40162.5430, device='cuda:0')
# loss for epoch: tensor(35799.3633, device='cuda:0')
# loss for epoch: tensor(34194.8047, device='cuda:0')
# loss for epoch: tensor(38710.9766, device='cuda:0')
# loss for epoch: tensor(41994.4805, device='cuda:0')
# loss for epoch: tensor(42337.0781, device='cuda:0')
# loss for epoch: tensor(38572.8633, device='cuda:0')
# loss for epoch: tensor(44868.1406, device='cuda:0')
# loss for epoch: tensor(37112.3086, device='cuda:0')
# loss for epoch: tensor(39222.4141, device='cuda:0')
# pretrain end module h2h tensor(29.7076, device='cuda:0') eig real 1.62772 eig img 1.43925
# clear session data 59 4929556480
# decode train finish
# decode end 2.76641244381
# loss for epoch: tensor(39504.6211, device='cuda:0')
# loss for epoch: tensor(40293.9180, device='cuda:0')
# loss for epoch: tensor(38111.5820, device='cuda:0')
# loss for epoch: tensor(38591.0469, device='cuda:0')
# loss for epoch: tensor(40639.5039, device='cuda:0')
# loss for epoch: tensor(38368.6953, device='cuda:0')
# loss for epoch: tensor(35781.4297, device='cuda:0')
# loss for epoch: tensor(37746.0625, device='cuda:0')
# loss for epoch: tensor(37912.9492, device='cuda:0')
# loss for epoch: tensor(38057.8984, device='cuda:0')
# loss for epoch: tensor(40058.5469, device='cuda:0')
# loss for epoch: tensor(38918.3359, device='cuda:0')
# loss for epoch: tensor(39106.8867, device='cuda:0')
# loss for epoch: tensor(38478.2305, device='cuda:0')
# loss for epoch: tensor(41834.7656, device='cuda:0')
# loss for epoch: tensor(38131.5352, device='cuda:0')
# loss for epoch: tensor(41226.7461, device='cuda:0')
# loss for epoch: tensor(43547.0469, device='cuda:0')
# loss for epoch: tensor(40016.7031, device='cuda:0')
# pretrain end module h2h tensor(29.6195, device='cuda:0') eig real 1.6147 eig img 1.38964
# clear session data 59 4929564672
# decode train finish
# decode end 2.72672826225
# loss for epoch: tensor(44399.8203, device='cuda:0')
# loss for epoch: tensor(41343.1523, device='cuda:0')
# loss for epoch: tensor(38887.9102, device='cuda:0')
# loss for epoch: tensor(42682.7109, device='cuda:0')
# loss for epoch: tensor(40166.2617, device='cuda:0')
# loss for epoch: tensor(41998.5664, device='cuda:0')
# loss for epoch: tensor(44795.1992, device='cuda:0')
# loss for epoch: tensor(35742.5625, device='cuda:0')
# loss for epoch: tensor(41841.0156, device='cuda:0')
# loss for epoch: tensor(40422.3984, device='cuda:0')
# loss for epoch: tensor(38881.6055, device='cuda:0')
# loss for epoch: tensor(28629.6309, device='cuda:0')
# loss for epoch: tensor(38428.3711, device='cuda:0')
# loss for epoch: tensor(44960.6367, device='cuda:0')
# loss for epoch: tensor(43172.8945, device='cuda:0')
# loss for epoch: tensor(43175.9961, device='cuda:0')
# loss for epoch: tensor(39154.8867, device='cuda:0')
# loss for epoch: tensor(41811.0664, device='cuda:0')
# loss for epoch: tensor(37764.3633, device='cuda:0')
# pretrain end module h2h tensor(29.5299, device='cuda:0') eig real 1.59513 eig img 1.38563
# clear session data 59 4929564672
# decode train finish
# decode end 2.81716580678
# loss for epoch: tensor(39959.4844, device='cuda:0')
# loss for epoch: tensor(47784.4102, device='cuda:0')
# loss for epoch: tensor(36357.9102, device='cuda:0')
# loss for epoch: tensor(42373.1562, device='cuda:0')
# loss for epoch: tensor(43317.9375, device='cuda:0')
# loss for epoch: tensor(40818.6094, device='cuda:0')
# loss for epoch: tensor(40768.8945, device='cuda:0')
# loss for epoch: tensor(38665.2227, device='cuda:0')
# loss for epoch: tensor(37415.5508, device='cuda:0')
# loss for epoch: tensor(40247.6523, device='cuda:0')
# loss for epoch: tensor(39683.9219, device='cuda:0')
# loss for epoch: tensor(37434.6055, device='cuda:0')
# loss for epoch: tensor(40639.4258, device='cuda:0')
# loss for epoch: tensor(39909.5977, device='cuda:0')
# loss for epoch: tensor(39045.0586, device='cuda:0')
# loss for epoch: tensor(38214.5312, device='cuda:0')
# loss for epoch: tensor(39327.8086, device='cuda:0')
# loss for epoch: tensor(43679.2344, device='cuda:0')
# loss for epoch: tensor(35939.1797, device='cuda:0')
# pretrain end module h2h tensor(29.4398, device='cuda:0') eig real 1.63725 eig img 1.36021
# clear session data 59 4929626112
# decode train finish
# decode end 2.93701366819
# loss for epoch: tensor(43653.9766, device='cuda:0')
# loss for epoch: tensor(39936.1016, device='cuda:0')
# loss for epoch: tensor(39776.8359, device='cuda:0')
# loss for epoch: tensor(36858.7383, device='cuda:0')
# loss for epoch: tensor(45180.6016, device='cuda:0')
# loss for epoch: tensor(42820.7031, device='cuda:0')
# loss for epoch: tensor(36838.0938, device='cuda:0')
# loss for epoch: tensor(37921.9766, device='cuda:0')
# loss for epoch: tensor(38683.8867, device='cuda:0')
# loss for epoch: tensor(37222.9648, device='cuda:0')
# loss for epoch: tensor(39156.0703, device='cuda:0')
# loss for epoch: tensor(41589.1719, device='cuda:0')
# loss for epoch: tensor(39951.2227, device='cuda:0')
# loss for epoch: tensor(44415.6641, device='cuda:0')
# loss for epoch: tensor(37542.9727, device='cuda:0')
# loss for epoch: tensor(35800.6797, device='cuda:0')
# loss for epoch: tensor(37033.0469, device='cuda:0')
# loss for epoch: tensor(38262.3086, device='cuda:0')
# loss for epoch: tensor(40202.7227, device='cuda:0')
# pretrain end module h2h tensor(29.3442, device='cuda:0') eig real 1.56107 eig img 1.29322
# clear session data 59 4929626112
# decode train finish
# decode end 2.91005127069
# loss for epoch: tensor(39968.0273, device='cuda:0')
# loss for epoch: tensor(41864.4297, device='cuda:0')
# loss for epoch: tensor(39380.2070, device='cuda:0')
# loss for epoch: tensor(42829.9766, device='cuda:0')
# loss for epoch: tensor(41490.8398, device='cuda:0')
# loss for epoch: tensor(42329.1250, device='cuda:0')
# loss for epoch: tensor(40775.4922, device='cuda:0')
# loss for epoch: tensor(38680.1875, device='cuda:0')
# loss for epoch: tensor(42018.2070, device='cuda:0')
# loss for epoch: tensor(39118.7070, device='cuda:0')
# loss for epoch: tensor(37238.4180, device='cuda:0')
# loss for epoch: tensor(40867.4570, device='cuda:0')
# loss for epoch: tensor(38159.1406, device='cuda:0')
# loss for epoch: tensor(40374.5547, device='cuda:0')
# loss for epoch: tensor(39519.9062, device='cuda:0')
# loss for epoch: tensor(41811.3945, device='cuda:0')
# loss for epoch: tensor(38985.8320, device='cuda:0')
# loss for epoch: tensor(38680.1953, device='cuda:0')
# loss for epoch: tensor(34423.3086, device='cuda:0')
# pretrain end module h2h tensor(29.2432, device='cuda:0') eig real 1.55421 eig img 1.28486
# clear session data 59 4929626112
# decode train finish
# decode end 2.80597416091
# loss for epoch: tensor(40052.8242, device='cuda:0')
# loss for epoch: tensor(42436.8047, device='cuda:0')
# loss for epoch: tensor(40605.1523, device='cuda:0')
# loss for epoch: tensor(37823.0742, device='cuda:0')
# loss for epoch: tensor(40724.1328, device='cuda:0')
# loss for epoch: tensor(37050.1172, device='cuda:0')
# loss for epoch: tensor(38301.6055, device='cuda:0')
# loss for epoch: tensor(41211.2148, device='cuda:0')
# loss for epoch: tensor(40208.6680, device='cuda:0')
# loss for epoch: tensor(42961.0273, device='cuda:0')
# loss for epoch: tensor(38919.2969, device='cuda:0')
# loss for epoch: tensor(36702.0234, device='cuda:0')
# loss for epoch: tensor(37107.3242, device='cuda:0')
# loss for epoch: tensor(38004.2656, device='cuda:0')
# loss for epoch: tensor(41361.5156, device='cuda:0')
# loss for epoch: tensor(40115.4180, device='cuda:0')
# loss for epoch: tensor(41383.7969, device='cuda:0')
# loss for epoch: tensor(39443.8828, device='cuda:0')
# loss for epoch: tensor(39162.1680, device='cuda:0')
# pretrain end module h2h tensor(29.1352, device='cuda:0') eig real 1.47232 eig img 1.27132
# clear session data 59 4930199552
# decode train finish
# decode end 2.82127125174
# loss for epoch: tensor(40946.1914, device='cuda:0')
# loss for epoch: tensor(37877.1719, device='cuda:0')
# loss for epoch: tensor(41213.0039, device='cuda:0')
# loss for epoch: tensor(38010.0703, device='cuda:0')
# loss for epoch: tensor(39080.7461, device='cuda:0')
# loss for epoch: tensor(42914.2695, device='cuda:0')
# loss for epoch: tensor(41060.2109, device='cuda:0')
# loss for epoch: tensor(37528.7539, device='cuda:0')
# loss for epoch: tensor(40892.8008, device='cuda:0')
# loss for epoch: tensor(34058.0195, device='cuda:0')
# loss for epoch: tensor(38467.2500, device='cuda:0')
# loss for epoch: tensor(37954.7500, device='cuda:0')
# loss for epoch: tensor(36151.8867, device='cuda:0')
# loss for epoch: tensor(43922.9844, device='cuda:0')
# loss for epoch: tensor(40326.6016, device='cuda:0')
# loss for epoch: tensor(38426.7852, device='cuda:0')
# loss for epoch: tensor(39358.1016, device='cuda:0')
# loss for epoch: tensor(42297.7891, device='cuda:0')
# loss for epoch: tensor(42284.4648, device='cuda:0')
# pretrain end module h2h tensor(29.0371, device='cuda:0') eig real 1.57641 eig img 1.20187
# clear session data 59 4930269184
# decode train finish
# decode end 2.95496997535
# loss for epoch: tensor(42375.4961, device='cuda:0')
# loss for epoch: tensor(41985.0820, device='cuda:0')
# loss for epoch: tensor(38018.4297, device='cuda:0')
# loss for epoch: tensor(40031.4531, device='cuda:0')
# loss for epoch: tensor(42272.7969, device='cuda:0')
# loss for epoch: tensor(39100.6016, device='cuda:0')
# loss for epoch: tensor(41611.4102, device='cuda:0')
# loss for epoch: tensor(38948.1992, device='cuda:0')
# loss for epoch: tensor(40750.6484, device='cuda:0')
# loss for epoch: tensor(38038.5273, device='cuda:0')
# loss for epoch: tensor(41433.5703, device='cuda:0')
# loss for epoch: tensor(37807.3320, device='cuda:0')
# loss for epoch: tensor(42170.0703, device='cuda:0')
# loss for epoch: tensor(35409.8008, device='cuda:0')
# loss for epoch: tensor(39423.7852, device='cuda:0')
# loss for epoch: tensor(41520.0234, device='cuda:0')
# loss for epoch: tensor(41542.5469, device='cuda:0')
# loss for epoch: tensor(44267.5430, device='cuda:0')
# loss for epoch: tensor(35996.2969, device='cuda:0')
# pretrain end module h2h tensor(28.9323, device='cuda:0') eig real 1.54367 eig img 1.22923
# clear session data 59 4930297856
# decode train finish
# decode end 2.89735614436
# loss for epoch: tensor(42166.5586, device='cuda:0')
# loss for epoch: tensor(41224.9414, device='cuda:0')
# loss for epoch: tensor(44111.2266, device='cuda:0')
# loss for epoch: tensor(43609.3672, device='cuda:0')
# loss for epoch: tensor(43887.5781, device='cuda:0')
# loss for epoch: tensor(39773.9453, device='cuda:0')
# loss for epoch: tensor(37247.3477, device='cuda:0')
# loss for epoch: tensor(40901.8633, device='cuda:0')
# loss for epoch: tensor(39205.5156, device='cuda:0')
# loss for epoch: tensor(39287.4414, device='cuda:0')
# loss for epoch: tensor(40052.5117, device='cuda:0')
# loss for epoch: tensor(38468.7344, device='cuda:0')
# loss for epoch: tensor(38744.1719, device='cuda:0')
# loss for epoch: tensor(40727.4922, device='cuda:0')
# loss for epoch: tensor(35795.7656, device='cuda:0')
# loss for epoch: tensor(37993.0469, device='cuda:0')
# loss for epoch: tensor(41822.1445, device='cuda:0')
# loss for epoch: tensor(36677.2148, device='cuda:0')
# loss for epoch: tensor(39141.4062, device='cuda:0')
# pretrain end module h2h tensor(28.8197, device='cuda:0') eig real 1.54337 eig img 1.18141
# clear session data 59 4931760128
# decode train finish
# decode end 2.84342549565
# loss for epoch: tensor(39567.4844, device='cuda:0')
# loss for epoch: tensor(36953.8164, device='cuda:0')
# loss for epoch: tensor(39087.0781, device='cuda:0')
# loss for epoch: tensor(40333.8750, device='cuda:0')
# loss for epoch: tensor(40183.7461, device='cuda:0')
# loss for epoch: tensor(41063.1094, device='cuda:0')
# loss for epoch: tensor(36274.0312, device='cuda:0')
# loss for epoch: tensor(40798.6602, device='cuda:0')
# loss for epoch: tensor(38145.7969, device='cuda:0')
# loss for epoch: tensor(41701.2109, device='cuda:0')
# loss for epoch: tensor(40249.9219, device='cuda:0')
# loss for epoch: tensor(36683.5078, device='cuda:0')
# loss for epoch: tensor(41925.0352, device='cuda:0')
# loss for epoch: tensor(38059.8945, device='cuda:0')
# loss for epoch: tensor(37826.6055, device='cuda:0')
# loss for epoch: tensor(39586.1875, device='cuda:0')
# loss for epoch: tensor(37797.8047, device='cuda:0')
# loss for epoch: tensor(40208.1797, device='cuda:0')
# loss for epoch: tensor(39014.7383, device='cuda:0')
# pretrain end module h2h tensor(28.7355, device='cuda:0') eig real 1.52215 eig img 1.17528
# clear session data 59 4931809280
# decode train finish
# decode end 2.87571958547
# loss for epoch: tensor(38745.5898, device='cuda:0')
# loss for epoch: tensor(37484.1953, device='cuda:0')
# loss for epoch: tensor(37438.2656, device='cuda:0')
# loss for epoch: tensor(38883.3828, device='cuda:0')
# loss for epoch: tensor(35659.4961, device='cuda:0')
# loss for epoch: tensor(40336.0117, device='cuda:0')
# loss for epoch: tensor(39065.9570, device='cuda:0')
# loss for epoch: tensor(40142.4297, device='cuda:0')
# loss for epoch: tensor(35753.7070, device='cuda:0')
# loss for epoch: tensor(37513.9414, device='cuda:0')
# loss for epoch: tensor(40616.7188, device='cuda:0')
# loss for epoch: tensor(43620.0547, device='cuda:0')
# loss for epoch: tensor(41575.7578, device='cuda:0')
# loss for epoch: tensor(37434.6992, device='cuda:0')
# loss for epoch: tensor(43431.1562, device='cuda:0')
# loss for epoch: tensor(35294.3828, device='cuda:0')
# loss for epoch: tensor(38585.6250, device='cuda:0')
# loss for epoch: tensor(43206.4727, device='cuda:0')
# loss for epoch: tensor(36778.5977, device='cuda:0')
# pretrain end module h2h tensor(28.6406, device='cuda:0') eig real 1.48879 eig img 1.19336
# clear session data 59 4931989504
# decode train finish
# decode end 3.00675585197
# loss for epoch: tensor(42595.1250, device='cuda:0')
# loss for epoch: tensor(36231.8984, device='cuda:0')
# loss for epoch: tensor(40274.6328, device='cuda:0')
# loss for epoch: tensor(42090.1406, device='cuda:0')
# loss for epoch: tensor(43290.0547, device='cuda:0')
# loss for epoch: tensor(42181.7930, device='cuda:0')
# loss for epoch: tensor(42429.6016, device='cuda:0')
# loss for epoch: tensor(34676.7070, device='cuda:0')
# loss for epoch: tensor(41857.7812, device='cuda:0')
# loss for epoch: tensor(36976., device='cuda:0')
# loss for epoch: tensor(39857.5586, device='cuda:0')
# loss for epoch: tensor(33624.4062, device='cuda:0')
# loss for epoch: tensor(44070.0078, device='cuda:0')
# loss for epoch: tensor(41821.9609, device='cuda:0')
# loss for epoch: tensor(40667.4570, device='cuda:0')
# loss for epoch: tensor(38904.4648, device='cuda:0')
# loss for epoch: tensor(35826.4609, device='cuda:0')
# loss for epoch: tensor(37816.7305, device='cuda:0')
# loss for epoch: tensor(37493.2773, device='cuda:0')
# pretrain end module h2h tensor(28.5592, device='cuda:0') eig real 1.54257 eig img 1.14054
# clear session data 59 4932022272
# decode train finish
# decode end 2.89366403877
# loss for epoch: tensor(34240.9375, device='cuda:0')
# loss for epoch: tensor(40589.8984, device='cuda:0')
# loss for epoch: tensor(42918., device='cuda:0')
# loss for epoch: tensor(39678.1953, device='cuda:0')
# loss for epoch: tensor(41246.4688, device='cuda:0')
# loss for epoch: tensor(40916.8047, device='cuda:0')
# loss for epoch: tensor(37307.6680, device='cuda:0')
# loss for epoch: tensor(40147.5703, device='cuda:0')
# loss for epoch: tensor(37469.6406, device='cuda:0')
# loss for epoch: tensor(32259.3164, device='cuda:0')
# loss for epoch: tensor(44707.5508, device='cuda:0')
# loss for epoch: tensor(42780.0469, device='cuda:0')
# loss for epoch: tensor(38334.7500, device='cuda:0')
# loss for epoch: tensor(46146.6797, device='cuda:0')
# loss for epoch: tensor(39596.9688, device='cuda:0')
# loss for epoch: tensor(37300.8047, device='cuda:0')
# loss for epoch: tensor(41896.3086, device='cuda:0')
# loss for epoch: tensor(36508.9492, device='cuda:0')
# loss for epoch: tensor(42378.5234, device='cuda:0')
# pretrain end module h2h tensor(28.4614, device='cuda:0') eig real 1.57773 eig img 1.15093
# clear session data 59 4932050944
# decode train finish
# decode end 2.86449315347
# loss for epoch: tensor(42234.8711, device='cuda:0')
# loss for epoch: tensor(36166.2773, device='cuda:0')
# loss for epoch: tensor(41989.6016, device='cuda:0')
# loss for epoch: tensor(36507.5898, device='cuda:0')
# loss for epoch: tensor(37676.1328, device='cuda:0')
# loss for epoch: tensor(40363.6211, device='cuda:0')
# loss for epoch: tensor(42823.2695, device='cuda:0')
# loss for epoch: tensor(38016.7969, device='cuda:0')
# loss for epoch: tensor(36687.3867, device='cuda:0')
# loss for epoch: tensor(42659.4922, device='cuda:0')
# loss for epoch: tensor(36147.9180, device='cuda:0')
# loss for epoch: tensor(37552.8828, device='cuda:0')
# loss for epoch: tensor(35071.3984, device='cuda:0')
# loss for epoch: tensor(41919.8594, device='cuda:0')
# loss for epoch: tensor(36635.2539, device='cuda:0')
# loss for epoch: tensor(42300.8320, device='cuda:0')
# loss for epoch: tensor(39162.3516, device='cuda:0')
# loss for epoch: tensor(35364.6133, device='cuda:0')
# loss for epoch: tensor(38465.5117, device='cuda:0')
# pretrain end module h2h tensor(28.3813, device='cuda:0') eig real 1.50525 eig img 1.12941
# clear session data 59 4932050944
# decode train finish
# decode end 2.74233026012
# loss for epoch: tensor(38437.2109, device='cuda:0')
# loss for epoch: tensor(36807.1250, device='cuda:0')
# loss for epoch: tensor(40649.2617, device='cuda:0')
# loss for epoch: tensor(39574.7773, device='cuda:0')
# loss for epoch: tensor(40262.7070, device='cuda:0')
# loss for epoch: tensor(44259.8438, device='cuda:0')
# loss for epoch: tensor(36838.4180, device='cuda:0')
# loss for epoch: tensor(40090.5156, device='cuda:0')
# loss for epoch: tensor(33128.0977, device='cuda:0')
# loss for epoch: tensor(39292.1172, device='cuda:0')
# loss for epoch: tensor(38723.3867, device='cuda:0')
# loss for epoch: tensor(41018.4688, device='cuda:0')
# loss for epoch: tensor(38836.0469, device='cuda:0')
# loss for epoch: tensor(42082.6797, device='cuda:0')
# loss for epoch: tensor(38326.8711, device='cuda:0')
# loss for epoch: tensor(37915.1680, device='cuda:0')
# loss for epoch: tensor(41037.5078, device='cuda:0')
# loss for epoch: tensor(39932.3945, device='cuda:0')
# loss for epoch: tensor(42544.1328, device='cuda:0')
# pretrain end module h2h tensor(28.3105, device='cuda:0') eig real 1.5302 eig img 1.15698
# clear session data 59 4932050944
# decode train finish
# decode end 2.92793685898
# loss for epoch: tensor(36877.8711, device='cuda:0')
# loss for epoch: tensor(35302.2461, device='cuda:0')
# loss for epoch: tensor(36438.7188, device='cuda:0')
# loss for epoch: tensor(46485.4609, device='cuda:0')
# loss for epoch: tensor(42828.4570, device='cuda:0')
# loss for epoch: tensor(41003.3164, device='cuda:0')
# loss for epoch: tensor(40347.6992, device='cuda:0')
# loss for epoch: tensor(38225.3789, device='cuda:0')
# loss for epoch: tensor(39428.4922, device='cuda:0')
# loss for epoch: tensor(39940.0391, device='cuda:0')
# loss for epoch: tensor(34029.9414, device='cuda:0')
# loss for epoch: tensor(40346.1719, device='cuda:0')
# loss for epoch: tensor(37821.6992, device='cuda:0')
# loss for epoch: tensor(45366.2109, device='cuda:0')
# loss for epoch: tensor(34519.1211, device='cuda:0')
# loss for epoch: tensor(41641.4414, device='cuda:0')
# loss for epoch: tensor(40368.7383, device='cuda:0')
# loss for epoch: tensor(36770.3750, device='cuda:0')
# loss for epoch: tensor(39280.9375, device='cuda:0')
# pretrain end module h2h tensor(28.2195, device='cuda:0') eig real 1.51626 eig img 1.18031
# clear session data 59 4932067328
# decode train finish
# decode end 2.86429163992
# loss for epoch: tensor(39777.4766, device='cuda:0')
# loss for epoch: tensor(42068.7266, device='cuda:0')
# loss for epoch: tensor(40128.5664, device='cuda:0')
# loss for epoch: tensor(36574.4375, device='cuda:0')
# loss for epoch: tensor(41645.8164, device='cuda:0')
# loss for epoch: tensor(40358.1953, device='cuda:0')
# loss for epoch: tensor(43049.8672, device='cuda:0')
# loss for epoch: tensor(39792.6211, device='cuda:0')
# loss for epoch: tensor(38324.8320, device='cuda:0')
# loss for epoch: tensor(41648.3438, device='cuda:0')
# loss for epoch: tensor(40972.0469, device='cuda:0')
# loss for epoch: tensor(40091.9414, device='cuda:0')
# loss for epoch: tensor(37563.6680, device='cuda:0')
# loss for epoch: tensor(37649.9453, device='cuda:0')
# loss for epoch: tensor(42211.8711, device='cuda:0')
# loss for epoch: tensor(39994.0859, device='cuda:0')
# loss for epoch: tensor(36925.1328, device='cuda:0')
# loss for epoch: tensor(40610.0469, device='cuda:0')
# loss for epoch: tensor(36124.6992, device='cuda:0')
# pretrain end module h2h tensor(28.1528, device='cuda:0') eig real 1.47336 eig img 1.13426
# clear session data 59 4932067328
# decode train finish
# decode end 2.73974404107
# loss for epoch: tensor(40169.3789, device='cuda:0')
# loss for epoch: tensor(43344.4883, device='cuda:0')
# loss for epoch: tensor(41286.3945, device='cuda:0')
# loss for epoch: tensor(39332.6094, device='cuda:0')
# loss for epoch: tensor(43196.4766, device='cuda:0')
# loss for epoch: tensor(37141.4531, device='cuda:0')
# loss for epoch: tensor(37829.3047, device='cuda:0')
# loss for epoch: tensor(39656.4414, device='cuda:0')
# loss for epoch: tensor(38292.4766, device='cuda:0')
# loss for epoch: tensor(40611.3828, device='cuda:0')
# loss for epoch: tensor(40361.8750, device='cuda:0')
# loss for epoch: tensor(42929.1211, device='cuda:0')
# loss for epoch: tensor(39962.3750, device='cuda:0')
# loss for epoch: tensor(40181.6016, device='cuda:0')
# loss for epoch: tensor(37475.1133, device='cuda:0')
# loss for epoch: tensor(41352.0586, device='cuda:0')
# loss for epoch: tensor(36000.6523, device='cuda:0')
# loss for epoch: tensor(41468.9023, device='cuda:0')
# loss for epoch: tensor(33262.6875, device='cuda:0')
# pretrain end module h2h tensor(28.0851, device='cuda:0') eig real 1.47515 eig img 1.11383
# clear session data 59 4932083712
# decode train finish
# decode end 2.76963894457
# loss for epoch: tensor(44322.7461, device='cuda:0')
# loss for epoch: tensor(43406.0859, device='cuda:0')
# loss for epoch: tensor(38104.0742, device='cuda:0')
# loss for epoch: tensor(45186.3086, device='cuda:0')
# loss for epoch: tensor(41180.0117, device='cuda:0')
# loss for epoch: tensor(37048.6094, device='cuda:0')
# loss for epoch: tensor(38227.5742, device='cuda:0')
# loss for epoch: tensor(43538.9492, device='cuda:0')
# loss for epoch: tensor(43070.0664, device='cuda:0')
# loss for epoch: tensor(42333.4453, device='cuda:0')
# loss for epoch: tensor(41498.7969, device='cuda:0')
# loss for epoch: tensor(37397.2969, device='cuda:0')
# loss for epoch: tensor(38409.5000, device='cuda:0')
# loss for epoch: tensor(37453.2930, device='cuda:0')
# loss for epoch: tensor(36047.2109, device='cuda:0')
# loss for epoch: tensor(38187.7695, device='cuda:0')
# loss for epoch: tensor(40491.3438, device='cuda:0')
# loss for epoch: tensor(41849.6992, device='cuda:0')
# loss for epoch: tensor(47690.7969, device='cuda:0')
# pretrain end module h2h tensor(28.0172, device='cuda:0') eig real 1.45355 eig img 1.14192
# clear session data 59 4944252928
# decode train finish
# decode end 2.76042448619
# loss for epoch: tensor(37112.7266, device='cuda:0')
# loss for epoch: tensor(37765.1562, device='cuda:0')
# loss for epoch: tensor(39689.9297, device='cuda:0')
# loss for epoch: tensor(37376.8672, device='cuda:0')
# loss for epoch: tensor(39646.5312, device='cuda:0')
# loss for epoch: tensor(39398.1914, device='cuda:0')
# loss for epoch: tensor(38157.1094, device='cuda:0')
# loss for epoch: tensor(37754.7383, device='cuda:0')
# loss for epoch: tensor(39953.7500, device='cuda:0')
# loss for epoch: tensor(38419.8672, device='cuda:0')
# loss for epoch: tensor(42547.9883, device='cuda:0')
# loss for epoch: tensor(34310.0156, device='cuda:0')
# loss for epoch: tensor(44936.2148, device='cuda:0')
# loss for epoch: tensor(42099.6836, device='cuda:0')
# loss for epoch: tensor(37127.5195, device='cuda:0')
# loss for epoch: tensor(41449.3594, device='cuda:0')
# loss for epoch: tensor(34282.8711, device='cuda:0')
# loss for epoch: tensor(40638.4102, device='cuda:0')
# loss for epoch: tensor(38135.8320, device='cuda:0')
# pretrain end module h2h tensor(27.9445, device='cuda:0') eig real 1.42684 eig img 1.10471
# clear session data 59 4944433152
# decode train finish
# decode end 2.69590189859
# loss for epoch: tensor(42295.9805, device='cuda:0')
# loss for epoch: tensor(37044.1836, device='cuda:0')
# loss for epoch: tensor(40389.6328, device='cuda:0')
# loss for epoch: tensor(40935.2305, device='cuda:0')
# loss for epoch: tensor(40942.4883, device='cuda:0')
# loss for epoch: tensor(47373.2461, device='cuda:0')
# loss for epoch: tensor(41202.6406, device='cuda:0')
# loss for epoch: tensor(41201.1328, device='cuda:0')
# loss for epoch: tensor(38892.1602, device='cuda:0')
# loss for epoch: tensor(35144.2305, device='cuda:0')
# loss for epoch: tensor(42793.2031, device='cuda:0')
# loss for epoch: tensor(39625.1680, device='cuda:0')
# loss for epoch: tensor(39784.8398, device='cuda:0')
# loss for epoch: tensor(36934.3047, device='cuda:0')
# loss for epoch: tensor(41742.1016, device='cuda:0')
# loss for epoch: tensor(39277.3789, device='cuda:0')
# loss for epoch: tensor(34858.9453, device='cuda:0')
# loss for epoch: tensor(38636.9297, device='cuda:0')
# loss for epoch: tensor(40189.0391, device='cuda:0')
# pretrain end module h2h tensor(27.8587, device='cuda:0') eig real 1.40751 eig img 1.0772
# clear session data 59 4944433152
# decode train finish
# decode end 2.72333480843
# loss for epoch: tensor(40181.0312, device='cuda:0')
# loss for epoch: tensor(41618.9648, device='cuda:0')
# loss for epoch: tensor(43046.2539, device='cuda:0')
# loss for epoch: tensor(39397.5898, device='cuda:0')
# loss for epoch: tensor(39935.7617, device='cuda:0')
# loss for epoch: tensor(36398.5312, device='cuda:0')
# loss for epoch: tensor(40071.3281, device='cuda:0')
# loss for epoch: tensor(40352.4570, device='cuda:0')
# loss for epoch: tensor(40505.8711, device='cuda:0')
# loss for epoch: tensor(40666.8750, device='cuda:0')
# loss for epoch: tensor(38063.3516, device='cuda:0')
# loss for epoch: tensor(39382.1836, device='cuda:0')
# loss for epoch: tensor(35722.7031, device='cuda:0')
# loss for epoch: tensor(39427.2344, device='cuda:0')
# loss for epoch: tensor(41955.4922, device='cuda:0')
# loss for epoch: tensor(40859.1680, device='cuda:0')
# loss for epoch: tensor(39341.4375, device='cuda:0')
# loss for epoch: tensor(40067.7109, device='cuda:0')
# loss for epoch: tensor(40550.7148, device='cuda:0')
# pretrain end module h2h tensor(27.7911, device='cuda:0') eig real 1.40848 eig img 1.04939
# clear session data 59 4944437248
# decode train finish
# decode end 2.66333449298
# loss for epoch: tensor(43654.4180, device='cuda:0')
# loss for epoch: tensor(34521.1055, device='cuda:0')
# loss for epoch: tensor(43268.9727, device='cuda:0')
# loss for epoch: tensor(34343.2539, device='cuda:0')
# loss for epoch: tensor(39028.8164, device='cuda:0')
# loss for epoch: tensor(40902.0469, device='cuda:0')
# loss for epoch: tensor(41495.1055, device='cuda:0')
# loss for epoch: tensor(42171.9180, device='cuda:0')
# loss for epoch: tensor(35611.5117, device='cuda:0')
# loss for epoch: tensor(36397.5820, device='cuda:0')
# loss for epoch: tensor(39582.3945, device='cuda:0')
# loss for epoch: tensor(44279.1172, device='cuda:0')
# loss for epoch: tensor(41545.7461, device='cuda:0')
# loss for epoch: tensor(40434.1367, device='cuda:0')
# loss for epoch: tensor(41293.5469, device='cuda:0')
# loss for epoch: tensor(37338.5352, device='cuda:0')
# loss for epoch: tensor(43344.5586, device='cuda:0')
# loss for epoch: tensor(35577.4258, device='cuda:0')
# loss for epoch: tensor(37894.6914, device='cuda:0')
# pretrain end module h2h tensor(27.7170, device='cuda:0') eig real 1.44013 eig img 1.06012
# clear session data 59 4944437248
# decode train finish
# decode end 2.88732496567
# loss for epoch: tensor(37986.4375, device='cuda:0')
# loss for epoch: tensor(37877.1289, device='cuda:0')
# loss for epoch: tensor(39159.1250, device='cuda:0')
# loss for epoch: tensor(40912.5312, device='cuda:0')
# loss for epoch: tensor(40464.2148, device='cuda:0')
# loss for epoch: tensor(40150.9492, device='cuda:0')
# loss for epoch: tensor(38996.1562, device='cuda:0')
# loss for epoch: tensor(43991.4414, device='cuda:0')
# loss for epoch: tensor(38729.7422, device='cuda:0')
# loss for epoch: tensor(39095.0078, device='cuda:0')
# loss for epoch: tensor(37784.2305, device='cuda:0')
# loss for epoch: tensor(41313.1602, device='cuda:0')
# loss for epoch: tensor(33082.5625, device='cuda:0')
# loss for epoch: tensor(43870.8516, device='cuda:0')
# loss for epoch: tensor(43690.2148, device='cuda:0')
# loss for epoch: tensor(38958.6953, device='cuda:0')
# loss for epoch: tensor(36114.9688, device='cuda:0')
# loss for epoch: tensor(39908.5977, device='cuda:0')
# loss for epoch: tensor(42876.2266, device='cuda:0')
# pretrain end module h2h tensor(27.6396, device='cuda:0') eig real 1.4358 eig img 1.02881
# clear session data 59 4944437248
# decode train finish
# decode end 2.77298451569
# loss for epoch: tensor(42516.9609, device='cuda:0')
# loss for epoch: tensor(35987.9688, device='cuda:0')
# loss for epoch: tensor(46856.5625, device='cuda:0')
# loss for epoch: tensor(38384.6445, device='cuda:0')
# loss for epoch: tensor(41871.6367, device='cuda:0')
# loss for epoch: tensor(40566.9258, device='cuda:0')
# loss for epoch: tensor(39683.5039, device='cuda:0')
# loss for epoch: tensor(38592.9688, device='cuda:0')
# loss for epoch: tensor(44070.4297, device='cuda:0')
# loss for epoch: tensor(38190.8125, device='cuda:0')
# loss for epoch: tensor(38064.8828, device='cuda:0')
# loss for epoch: tensor(40190.3203, device='cuda:0')
# loss for epoch: tensor(42270.8438, device='cuda:0')
# loss for epoch: tensor(32568.8750, device='cuda:0')
# loss for epoch: tensor(39336.6523, device='cuda:0')
# loss for epoch: tensor(48547.7578, device='cuda:0')
# loss for epoch: tensor(36303.9453, device='cuda:0')
# loss for epoch: tensor(40843.9922, device='cuda:0')
# loss for epoch: tensor(36773.7109, device='cuda:0')
# pretrain end module h2h tensor(27.5857, device='cuda:0') eig real 1.47032 eig img 1.03614
# clear session data 59 4975243264
# decode train finish
# decode end 2.68095292508
# loss for epoch: tensor(43382.7461, device='cuda:0')
# loss for epoch: tensor(42663.5391, device='cuda:0')
# loss for epoch: tensor(39502.9023, device='cuda:0')
# loss for epoch: tensor(37433.2266, device='cuda:0')
# loss for epoch: tensor(40725.5352, device='cuda:0')
# loss for epoch: tensor(41118.9453, device='cuda:0')
# loss for epoch: tensor(42897.3750, device='cuda:0')
# loss for epoch: tensor(44655.2734, device='cuda:0')
# loss for epoch: tensor(36092.1523, device='cuda:0')
# loss for epoch: tensor(39482.9336, device='cuda:0')
# loss for epoch: tensor(42388.9258, device='cuda:0')
# loss for epoch: tensor(36967.0625, device='cuda:0')
# loss for epoch: tensor(38658.6445, device='cuda:0')
# loss for epoch: tensor(35368.5938, device='cuda:0')
# loss for epoch: tensor(38300.5078, device='cuda:0')
# loss for epoch: tensor(36537.8398, device='cuda:0')
# loss for epoch: tensor(37541.4922, device='cuda:0')
# loss for epoch: tensor(44923.6172, device='cuda:0')
# loss for epoch: tensor(42539.7500, device='cuda:0')
# pretrain end module h2h tensor(27.5009, device='cuda:0') eig real 1.43698 eig img 1.02431
# clear session data 59 4975435776
# decode train finish
# decode end 2.75958649928
# loss for epoch: tensor(41535.7188, device='cuda:0')
# loss for epoch: tensor(41095.8789, device='cuda:0')
# loss for epoch: tensor(40189.2852, device='cuda:0')
# loss for epoch: tensor(37865.0312, device='cuda:0')
# loss for epoch: tensor(38643.1484, device='cuda:0')
# loss for epoch: tensor(40546.9336, device='cuda:0')
# loss for epoch: tensor(45749.1914, device='cuda:0')
# loss for epoch: tensor(39992.6367, device='cuda:0')
# loss for epoch: tensor(41443.4648, device='cuda:0')
# loss for epoch: tensor(38711.0625, device='cuda:0')
# loss for epoch: tensor(39920.9688, device='cuda:0')
# loss for epoch: tensor(46006.5586, device='cuda:0')
# loss for epoch: tensor(41700.9258, device='cuda:0')
# loss for epoch: tensor(42820.8555, device='cuda:0')
# loss for epoch: tensor(41369.1328, device='cuda:0')
# loss for epoch: tensor(36875.9648, device='cuda:0')
# loss for epoch: tensor(40526.0195, device='cuda:0')
# loss for epoch: tensor(45892.0391, device='cuda:0')
# loss for epoch: tensor(39259.0547, device='cuda:0')
# pretrain end module h2h tensor(27.4446, device='cuda:0') eig real 1.43686 eig img 1.03582
# clear session data 59 4975624192
# decode train finish
# decode end 2.72057367118
# loss for epoch: tensor(40025.2266, device='cuda:0')
# loss for epoch: tensor(40086.4531, device='cuda:0')
# loss for epoch: tensor(35759.5664, device='cuda:0')
# loss for epoch: tensor(41462.2422, device='cuda:0')
# loss for epoch: tensor(44675.6094, device='cuda:0')
# loss for epoch: tensor(39181.6836, device='cuda:0')
# loss for epoch: tensor(38538.0977, device='cuda:0')
# loss for epoch: tensor(45791.7305, device='cuda:0')
# loss for epoch: tensor(41030.5312, device='cuda:0')
# loss for epoch: tensor(38867.9023, device='cuda:0')
# loss for epoch: tensor(44981.3281, device='cuda:0')
# loss for epoch: tensor(42318.9414, device='cuda:0')
# loss for epoch: tensor(36922.9102, device='cuda:0')
# loss for epoch: tensor(39593.1719, device='cuda:0')
# loss for epoch: tensor(40011.4609, device='cuda:0')
# loss for epoch: tensor(38173.9961, device='cuda:0')
# loss for epoch: tensor(40217.2383, device='cuda:0')
# loss for epoch: tensor(40329.8633, device='cuda:0')
# loss for epoch: tensor(38706.6289, device='cuda:0')
# pretrain end module h2h tensor(27.3966, device='cuda:0') eig real 1.43513 eig img 1.01371
# clear session data 59 4975771648
# decode train finish
# decode end 2.77003456975
# loss for epoch: tensor(38994.1641, device='cuda:0')
# loss for epoch: tensor(39168.4141, device='cuda:0')
# loss for epoch: tensor(39149.0234, device='cuda:0')
# loss for epoch: tensor(39163.0273, device='cuda:0')
# loss for epoch: tensor(37150.1562, device='cuda:0')
# loss for epoch: tensor(41654.4922, device='cuda:0')
# loss for epoch: tensor(37882.6523, device='cuda:0')
# loss for epoch: tensor(39904.2305, device='cuda:0')
# loss for epoch: tensor(39269.3750, device='cuda:0')
# loss for epoch: tensor(38786.5703, device='cuda:0')
# loss for epoch: tensor(34468.2891, device='cuda:0')
# loss for epoch: tensor(46388.4180, device='cuda:0')
# loss for epoch: tensor(36291.4609, device='cuda:0')
# loss for epoch: tensor(41665.4805, device='cuda:0')
# loss for epoch: tensor(39251.0898, device='cuda:0')
# loss for epoch: tensor(39980.8242, device='cuda:0')
# loss for epoch: tensor(36881.3281, device='cuda:0')
# loss for epoch: tensor(38805.4102, device='cuda:0')
# loss for epoch: tensor(42877.0742, device='cuda:0')
# pretrain end module h2h tensor(27.3421, device='cuda:0') eig real 1.4195 eig img 0.984025
# clear session data 59 4975771648
# decode train finish
# decode end 2.75354192565
# loss for epoch: tensor(38625.9492, device='cuda:0')
# loss for epoch: tensor(42582.5664, device='cuda:0')
# loss for epoch: tensor(41393.3594, device='cuda:0')
# loss for epoch: tensor(38883.6016, device='cuda:0')
# loss for epoch: tensor(40961.1250, device='cuda:0')
# loss for epoch: tensor(40256.6016, device='cuda:0')
# loss for epoch: tensor(37807.1523, device='cuda:0')
# loss for epoch: tensor(34397.2812, device='cuda:0')
# loss for epoch: tensor(39197.5312, device='cuda:0')
# loss for epoch: tensor(40041.9531, device='cuda:0')
# loss for epoch: tensor(37517.7305, device='cuda:0')
# loss for epoch: tensor(34998.2734, device='cuda:0')
# loss for epoch: tensor(37827.5898, device='cuda:0')
# loss for epoch: tensor(37455.2266, device='cuda:0')
# loss for epoch: tensor(40010.1758, device='cuda:0')
# loss for epoch: tensor(39808.7070, device='cuda:0')
# loss for epoch: tensor(41214.9648, device='cuda:0')
# loss for epoch: tensor(38751.5000, device='cuda:0')
# loss for epoch: tensor(44298.3594, device='cuda:0')
# pretrain end module h2h tensor(27.2967, device='cuda:0') eig real 1.44145 eig img 0.981871
# clear session data 59 4975988736
# decode train finish
# decode end 2.75362198706

# %%
Precision = []
Pretest =  PretrainTest(weight_write = 'weights{}/rnn_1515tanh512_checkpoint'.format(1), holes = 0)
Pretest.pregame.net.load_state_dict(torch.load('weights1/rnn_1515tanh512_checkpoint1'))
Predicts, targets, hiddens = Pretest.pregame.fulltest(batchsize=1)

# %%
dhs = hiddens[:-1] - hiddens[1:] 
plt.plot([torch.norm(dh).cpu().data.numpy() for dh in dhs])

# %%
Predicts[0].size(), targets[0].size()
# Out:
# (torch.Size([1, 5]), torch.Size([1, 5]))

# %%
[(np.argmax(pre[0].cpu().data.numpy()), np.argmax(target[0].cpu().data.numpy())) for pre, target in zip(Predicts, targets)]
# Out:
# [(3, 3),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 1),
#  (3, 1),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 3),
#  (3, 0),
#  (3, 3),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 1),
#  (3, 0),
#  (3, 1),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 2),
#  (3, 2),
#  (3, 0),
#  (3, 2),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 2),
#  (3, 2),
#  (3, 2),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 3),
#  (3, 0),
#  (3, 0),
#  (3, 1),
#  (3, 1),
#  (3, 1),
#  (3, 0),
#  (3, 0),
#  (3, 1),
#  (3, 1),
#  (3, 1),
#  (3, 0),
#  (3, 1),
#  (3, 1),
#  (3, 1),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 1),
#  (3, 0),
#  (3, 1),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 4),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 1),
#  (3, 1),
#  (3, 1)]

# %%
[np.argmax(predict[0].cpu().data.numpy()) for predict in Predicts]
# Out:
# [4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4]

# %%
torch.norm(Pretest.pregame.net.h2h)
Weff = Pretest.pregame.net.h2h #+ game.net.h2o.matmul(game.net.a2h)
#     plt.figure()
plt.scatter (Weff.eig()[0][:,0].cpu().data.numpy(), Weff.eig()[0][:,1].cpu().data.numpy(), label = trial)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-462fbe32b945> in <module>()
#       2 Weff = Pretest.pregame.net.h2h #+ game.net.h2o.matmul(game.net.a2h)
#       3 #     plt.figure()
# ----> 4 plt.scatter (Weff.eig()[0][:,0].cpu().data.numpy(), Weff.eig()[0][:,1].cpu().data.numpy(), label = trial)
#
# NameError: name 'trial' is not defined

# %%
Pretest.pregame.decoder.I2p
# Out:
# Parameter containing:
# tensor([[ 0.2888,  0.5131,  0.5626, -0.0890,  0.4715],
#         [-0.2693, -0.3602, -1.1068, -0.4934, -1.0088],
#         [ 0.2659,  0.2278,  0.3608,  0.1596, -0.0190],
#         ...,
#         [-0.2615, -0.0635, -0.1631, -0.2355, -0.0146],
#         [-1.3577, -0.3358,  0.3691, -1.4696, -0.0919],
#         [-0.1545, -0.1073, -0.9971, -0.6174, -1.0688]], device='cuda:0')

# %% [markdown]
# Precision_blank2 = []
#
# for trial in range(30):
#     for size in [15, 55, 85]:
#         print ('trial', trial)
#         Pretest =  PretrainTest(holes = 0, weight_write = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(1, 0))
#         Prec = Pretest.decode(size_range = [size], size_test = [size])
#         Precision_blank2.append(Prec)
#
#     np.save('Precision_blank.npy', Precision_blank2)

# %% [markdown]
# Precision_blank_r = []
#
# for trial in range(30):
#     print ('trial', trial)
#     Pretest =  PretrainTest(holes = 0, weight_write = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(1, 0))
#     Prec = Pretest.decode(epsilon = 1)
#     Precision_blank_r.append(Prec)
#
# np.save('Precision_blank_random.npy', Precision_blank_r)

# %%
Precision_blank_r = []

for trial in range(30, 40): 
    print ('trial', trial)
    Pretest =  PretrainTest(holes = 0, weight_write = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(1, 0))
    Prec = Pretest.decode(epsilon = 1)
    Precision_blank_r.append(Prec)

np.save('Precision_blank_random_2.npy', Precision_blank_r)
# Out:
# trial 30
# clear session data 159 2469203968
# decode train finish
# decode end 4.452293213645052 6.130852042460522
# trial 31
# clear session data 159 2434461696
# decode train finish
# decode end 6.220524009337546 5.703354323962497
# trial 32
# clear session data 159 2466897920
# decode train finish
# decode end 4.60266828690292 7.021793003832404
# trial 33
# clear session data 159 2466897920
# decode train finish
# decode end 5.404164367808777 5.154143127419681
# trial 34
# clear session data 159 2467168256
# decode train finish
# decode end 4.291497006149317 8.02686202937978
# trial 35
# clear session data 159 2467168256
# decode train finish
# decode end 4.5859875060979505 6.339443789887617
# trial 36
# clear session data 159 2467168256
# decode train finish
# decode end 5.372852841452577 5.318617829068014
# trial 37
# clear session data 159 2467168256
# decode train finish
# decode end 5.193085838762101 6.44754837941729
# trial 38
# clear session data 159 2471460864
# decode train finish
# decode end 4.950399358757522 6.135692227776004
# trial 39
# clear session data 159 2471460864
# decode train finish
# decode end 4.276768594982638 6.578457887250422

# %%
Precision_blank = np.load('Precision_blank.npy')
plt.plot([pre[0] for pre in Precision_blank], 'ks-')
plt.plot([pre[1] for pre in Precision_blank], 'ks--')

# %%
Precision_blank = np.load('Precision_blank.npy')
Precision_blank_random = np.load('Precision_blank_random.npy')
pre0_s = [pre[0] for pre in Precision_blank]
pre0_sr = [pre[0] for pre in Precision_blank_random]
plt.scatter(pre0_sr, pre0_s)
plt.plot(np.linspace(2.5, 6, 100), np.linspace(2.5, 6, 100), 'k--')
np.where(np.abs((np.array(pre0_s) - np.array(pre0_sr)))<0.2)
# Out:
# (array([ 1, 24]),)

# %%
pre0_l = [pre[1] for pre in Precision_blank]
pre0_lr = [pre[1] for pre in Precision_blank_random]
plt.scatter(pre0_l, pre0_lr)
plt.plot(np.linspace(2.5, 6, 100), np.linspace(2.5, 6, 100), 'k--')
plt.figure()
plt.plot(np.abs(np.array(pre0_lr) - np.array(pre0_l)))
np.where(np.abs((np.array(pre0_l) - np.array(pre0_lr)))<0.2)
# Out:
# (array([3]),)

# %%
# another results before
Precision_blank = np.load('Precision_blank.npy')
plt.plot([pre[0][0] for pre in Precision_blank], 'ks-')
plt.plot([pre[1][0] for pre in Precision_blank], 'ks--')

# %% [markdown]
# ### Decoding along Q learning
# ***Check if behaviour actually also changes prediction, that could explain the powerfulness of action loop on shaping the predictiivity, even though its shows more power in version without action, execept the first iteration, all the others seems to have the trends of increasing decodibility in small size end with q learning, also no matter their intial decoding value , the later stage values are similar**
#
# **The decoding level might be very low associate with the good generalized states, which will show that the good generalized one are without good decoding, in another way, the one with very nice transient and good decoding might not decode well, which will show later**
#
# **The trends of decoding-performance is inverse, the better performance with q leanring,  the worse decoding level.**

# %%
Q_learn_decode = []
for iters, trial in enumerate(5 * [38]):
    Precision_qlearn = []
    Pretest =  PretrainTest(holes = 0, weight_write = 'weights_cpu/rnn_1515tanh512_checkpoint0', inputs_type=(1, 0))
    for i in range(11): 
        print ('iterations', i)
        if i == 0 : 
            weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)
        else:
            weight = 'weights2/rnn_1515tanh512_checkpoint{}_{}_{}'.format(trial, iters, i-1)
        Prec = Pretest.decode(weight = weight, size_range = [55], size_test = [10])
        Precision_qlearn.append(Prec)
    Q_learn_decode.append(Precision_qlearn)
    np.save('Precision_qlearn.npy', Q_learn_decode)
# Out:
# iterations 0
# clear session data 159 2742517760
# decode train finish
# decode end 26.904373982945536
# iterations 1
# clear session data 159 2772934656
# decode train finish
# decode end 43.13429222442041
# iterations 2
# clear session data 159 2728103936
# decode train finish
# decode end 37.729624275059216
# iterations 3
# clear session data 159 2773229568
# decode train finish
# decode end 27.643294075004057
# iterations 4
# clear session data 159 2772996096
# decode train finish
# decode end 38.45896376556499
# iterations 5
# clear session data 159 2772951040
# decode train finish
# decode end 37.22295108406419
# iterations 6
# clear session data 159 2728464384
# decode train finish
# decode end 37.48871031191211
# iterations 7
# clear session data 159 2773020672
# decode train finish
# decode end 38.34380436790539
# iterations 8
# clear session data 159 2728300544
# decode train finish
# decode end 43.24357143215411
# iterations 9
# clear session data 159 2729123840
# decode train finish
# decode end 39.86033554321658
# iterations 10
# clear session data 159 2729467904
# decode train finish
# decode end 42.2533263093354
# iterations 0
# clear session data 159 2773200896
# decode train finish
# decode end 25.96496401549363
# iterations 1
# clear session data 159 2773262336
# decode train finish
# decode end 42.12787637380131
# iterations 2
# clear session data 159 2773307392
# decode train finish
# decode end 38.8865589902879
# iterations 3
# clear session data 159 2729365504
# decode train finish
# decode end 36.44915209955838
# iterations 4
# clear session data 159 2774315008
# decode train finish
# decode end 38.81017630938568
# iterations 5
# clear session data 159 2774355968
# decode train finish
# decode end 41.0871507559353
# iterations 6
# clear session data 159 2729586688
# decode train finish
# decode end 35.05010870280447
# iterations 7
# clear session data 159 2729447424
# decode train finish
# decode end 36.77736549362065
# iterations 8
# clear session data 159 2729541632
# decode train finish
# decode end 35.35197073669754
# iterations 9
# clear session data 159 2729496576
# decode train finish
# decode end 43.393154830015774
# iterations 10
# clear session data 159 2774163456
# decode train finish
# decode end 38.89961889987717
# iterations 0
# clear session data 159 2729496576
# decode train finish
# decode end 26.196496089803578
# iterations 1
# clear session data 159 2774614016
# decode train finish
# decode end 36.50159116391722
# iterations 2
# clear session data 159 2730872832
# decode train finish
# decode end 30.58493381601344
# iterations 3
# clear session data 159 2773663744
# decode train finish
# decode end 37.680401696289586
# iterations 4
# clear session data 159 2773655552
# decode train finish
# decode end 39.96312918309486
# iterations 5
# clear session data 159 2773848064
# decode train finish
# decode end 40.56313410723666
# iterations 6
# clear session data 159 2774499328
# decode train finish
# decode end 39.07896625421665
# iterations 7
# clear session data 159 2773516288
# decode train finish
# decode end 39.194667728126404
# iterations 8
# clear session data 159 2774339584
# decode train finish
# decode end 39.854186395829544
# iterations 9
# clear session data 159 2774589440
# decode train finish
# decode end 43.00455048171683
# iterations 10
# clear session data 159 2729631744
# decode train finish
# decode end 45.33586204722582
# iterations 0
# clear session data 159 2773831680
# decode train finish
# decode end 26.068525037310682
# iterations 1
# clear session data 159 2773823488
# decode train finish
# decode end 38.55883046995103
# iterations 2
# clear session data 159 2775007232
# decode train finish
# decode end 33.65785269193219
# iterations 3
# clear session data 159 2774982656
# decode train finish
# decode end 45.12972197054195
# iterations 4
# clear session data 159 2773872640
# decode train finish
# decode end 45.324367881526605
# iterations 5
# clear session data 159 2774941696
# decode train finish
# decode end 47.688949041840864
# iterations 6
# clear session data 159 2774888448
# decode train finish
# decode end 38.88015817119192
# iterations 7
# clear session data 159 2773782528
# decode train finish
# decode end 46.58340065720649
# iterations 8
# clear session data 159 2730106880
# decode train finish
# decode end 37.958632577661774
# iterations 9
# clear session data 159 2730143744
# decode train finish
# decode end 41.86119541156547
# iterations 10
# clear session data 159 2774630400
# decode train finish
# decode end 40.84322270534216
# iterations 0
# clear session data 159 2729496576
# decode train finish
# decode end 26.885839657090262
# iterations 1
# clear session data 159 2729107456
# decode train finish
# decode end 29.48064248607658
# iterations 2
# clear session data 159 2775097344
# decode train finish
# decode end 35.35695681986117
# iterations 3
# clear session data 159 2729295872
# decode train finish
# decode end 35.70527694008747
# iterations 4
# clear session data 159 2730360832
# decode train finish
# decode end 36.22526708145885
# iterations 5
# clear session data 159 2729295872
# decode train finish
# decode end 40.888485940267834
# iterations 6
# clear session data 159 2773622784
# decode train finish
# decode end 37.93704592195409
# iterations 7
# clear session data 159 2730270720
# decode train finish
# decode end 40.32515965141511
# iterations 8
# clear session data 159 2775261184
# decode train finish
# decode end 45.021537721016166
# iterations 9
# clear session data 159 2730221568
# decode train finish
# decode end 41.68558187664249
# iterations 10
# clear session data 159 2774433792
# decode train finish
# decode end 45.53493513125326

# %%
Performance = []
for trial in [0, 7, 9, 13, 15]:
    Precision_qlearn = []
    Pretest =  PretrainTest(holes = 0, weight_write = 'weights1_new/rnn_1515tanh512_checkpoint0', inputs_type=(1, 0))
    performance = []
    for i in range(10):
        Pretest0 = PretrainTest(holes = 0, weight_write = 'weights2/rnn_1515tanh512_checkpoint0_{}_{}'.format(trial, i), inputs_type=(1, 0))
        Pretest0.TestAllSizes(size_range = [15], limit_set = 8, test_size = 0)
        print (Pretest0.Performance)
        performance.append(Pretest0.Performance)
    Performance.append(performance)
    np.save('Performance_qlearn.npy', Performance)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-ef1dede50a0e> in <module>()
#       6     for i in range(10):
#       7         Pretest0 = PretrainTest(holes = 0, weight_write = 'weights2/rnn_1515tanh512_checkpoint0_{}_{}'.format(trial, i), inputs_type=(1, 0))
# ----> 8         Pretest0.TestAllSizes(size_range = [15], limit_set = 8, test_size = 0)
#       9         print (Pretest0.Performance)
#      10         performance.append(Pretest0.Performance)
#
# <ipython-input-2-c5da335e4a40> in TestAllSizes(self, size_range, limit_set, test_size)
#      96
#      97     def TestAllSizes(self, size_range = np.arange(15, 86, 10), limit_set = 8, test_size = None):
# ---> 98         self.game.net.load_state_dict(torch.load(self.weight))
#      99         self.Performance = []
#     100         for size in size_range:
#
# ~/anaconda3/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     299             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     300         new_fd = True
# --> 301         f = open(f, 'rb')
#     302     try:
#     303         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weights2/rnn_1515tanh512_checkpoint0_0_0'

# %%
for qlearn in Q_learn_decode:
    plt.plot(qlearn, '.-')
plt.figure()
plt.plot(np.mean(np.array(Q_learn_decode), axis = 0))

# %% [markdown]
# **A coherent result here is threhold kind behaviour of decode vs performance, after decode smaller than 10, the performance rises.  The resutls is showeing that the learning rate vs performance doesn't characterize the threshold kind behaviour of performance change.  It is only after lr = -5, the performance begins to rise , while the learning rate - performance curve creates a fake trends for first few points.  This is not shown by explaination factor calculated by covariance.  **
