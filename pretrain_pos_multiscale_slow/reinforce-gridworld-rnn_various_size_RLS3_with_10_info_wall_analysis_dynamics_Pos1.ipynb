# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#quick-start" data-toc-modified-id="quick-start-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>quick start</a></span><ul class="toc-item"><li><span><a href="#Resources" data-toc-modified-id="Resources-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Resources</a></span></li></ul></li><li><span><a href="#FULL-MODEL" data-toc-modified-id="FULL-MODEL-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>FULL MODEL</a></span><ul class="toc-item"><li><span><a href="#Packages" data-toc-modified-id="Packages-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Packages</a></span><ul class="toc-item"><li><span><a href="#Qnetwork" data-toc-modified-id="Qnetwork-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Qnetwork</a></span></li></ul></li><li><span><a href="#POMDP-RNN-Game" data-toc-modified-id="POMDP-RNN-Game-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>POMDP RNN Game</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#Standard-setting：-grid-=--(3,7)，-holes-=-0" data-toc-modified-id="Standard-setting：-grid-=--(3,7)，-holes-=-0-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Standard setting： grid =  (3,7)， holes = 0</a></span></li><li><span><a href="#Model-Tranining" data-toc-modified-id="Model-Tranining-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Model Tranining</a></span></li><li><span><a href="#decoding-vs-performance" data-toc-modified-id="decoding-vs-performance-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>decoding vs performance</a></span></li><li><span><a href="#learning-rate-vs-performance" data-toc-modified-id="learning-rate-vs-performance-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>learning rate vs performance</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#Anlytic-part-,-check-the-behaviour-correspond-to-each-decoding-level-and-explain-why" data-toc-modified-id="Anlytic-part-,-check-the-behaviour-correspond-to-each-decoding-level-and-explain-why-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>Anlytic part , check the behaviour correspond to each decoding level and explain why</a></span></li></ul></li><li><span><a href="#PCA" data-toc-modified-id="PCA-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>PCA</a></span></li></ul></li></ul></div>

# %% [markdown]
# # quick start

# %% [markdown]
# **Somethings to change**:
#
# 1.  find the eigen point correspoing mode, W and PC relation
#
# 2.  Make the analysis more stable by using last three weights
#
# 3.  Try to find decoding performance in 10-50 setting
#
# 4.  Use more range to measure not only 15 55 85
#
# 5.  Same trends of increasing img, but failed prediction, what is other factors?  What really predicts the limit cycle type strategy?
#
# 6.  Relation of PC dimension and real trace shape, if too high D will make the real game hard?

# %% [markdown]
# ## Resources
#
# * [*The* Reinforcement learning book from Sutton & Barto](http://incompleteideas.net/sutton/book/the-book-2nd.html)
# * [The REINFORCE paper from Ronald J. Williams (1992)](http://www-anw.cs.umass.edu/~barto/courses/cs687/williams92simple.pdf)

# %% [markdown]
# # FULL MODEL

# %% [markdown]
# ## Packages

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from itertools import count
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
from torch.autograd import Variable
from torch.nn import init
from torch.nn import DataParallel
from torch.utils.data import DataLoader

import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib.animation
import seaborn as sns
from IPython.display import HTML

import pretrain
from pretrain import *

import pandas as pd

import navigation2
from navigation2 import *

import sklearn
from sklearn.svm import SVC

import scipy
from scipy.spatial import distance
from scipy import signal

import Nets 
from Nets import *

import dynamics
from dynamics import * 



# %pylab inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/tie/.conda/envs/torch/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### Qnetwork
#
# To select actions we take maximum of Q value, corresponding to certain move.

# %% [markdown]
# For the liquid state approach to work, you need a lot of neurons as surplus or enough hidden to hidden connectivity to make it have an effect.

# %% [markdown]
# ##  test Pretrain loss
# In this game , we use a new reward function determined by game, if the agent achieves the goal before 50, reward is 1. If time pass 50 reward is 0.5, once time pass 100 agent gets a reward of -0.5 .  Practically, this is found to be easier to learn than the rewards as a continous function of time.  Tf the agent learns to search in a efficient way, the largest possible way for search is to firstly arrive at corner then goes to the goal, which, takes about 50 steps, it is reasonble to make 50 and 100 as milestone thing.  Also in principe as the game doesn't have a timer , it is not if it can use a reward as funtion of time

# %% [markdown]
# 3 condition for ending , when pass time limit, game over

# %% [markdown]
# For weight update, it seems to be better do it after episode, as it makes non-sense evaluate strategy during episode, but a the end. Also, it is much quicker.

# %% [markdown]
# A programming of MDP here, hidden state is as state of enviroment

# %% [markdown]
# Training from zero seems to be better because it will allow the agent to explore from new

# %% [markdown]
# **A coherent result here is threhold kind behaviour of decode vs performance, after decode smaller than 10, the performance rises.  The resutls is showeing that the learning rate vs performance doesn't characterize the threshold kind behaviour of performance change.  It is only after lr = -5, the performance begins to rise , while the learning rate - performance curve creates a fake trends for first few points.  This is not shown by explaination factor calculated by covariance.  **

# %%
def placefield_target(pos): 
    field =np.zeros((2, 20 + 4))
    for k in range(2):
        for i in range(field.shape[1]): 
        # distance generation 
            field[k, i] = (i- pos[k]) ** 2 
    # gaussian density, but before exponential to help learning identity mapping input to output
    field = torch.from_numpy(field).resize(1, 2 * (20 + 4)).float()
    return field

# %%
Entropy = []
Entropy_ref = []
for iters, trial in enumerate(np.arange(0, 5, 1)):
    beta = 1e-2 
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    Poss = []
    hs = []
    for i in range(10):
        Pos,h, dh, a, s, reward = trajectory(game, pos0 = (np.random.randint(2, 17), np.random.randint(2, 17)), epsilon=0.5)
        det = np.sum(s[1:]- s[:-1], axis = 1)
        T = np.where(det!=0)
        if len(T[0])>0:
            Poss.extend(Pos[T[0][0]:-1])
            hs.extend(h[T[0][0]:])
    placefield = [placefield_target(pos).data.numpy() for pos in Poss]
    predict = [(torch.from_numpy(h).matmul(game.net.h2p1) + game.net.bp1).data.numpy() for h in hs]
#     print ('mse', np.linalg.norm(np.array(placefield) - np.array(predict)))
    def probs(field):
        prob = np.exp(-beta * field.ravel())/np.sum(np.exp(-beta * field.ravel()))
        return prob
    Prob = np.array([probs(f) for f in placefield])
    Prob_p = np.array([probs(f) for f in predict])
    Entropy.append(-np.mean(Prob * np.log(Prob_p + 1e-5)))
    Entropy_ref.append(-np.mean(Prob * np.log(Prob + 1e-5)))

# %%
plt.plot(Entropy)
plt.plot(Entropy_ref)

# %%
Entropy = []
Entropy_ref = []
for iters, trial in enumerate(np.arange(0, 5, 1)):
    beta = 3 * 1e-2 
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    Poss = []
    hs = []
    for i in range(10):
        Pos,h, dh, a, s, reward = trajectory(game, pos0 = (np.random.randint(2, 17), np.random.randint(2, 17)), epsilon=0.5)
        det = np.sum(s[1:]- s[:-1], axis = 1)
        T = np.where(det!=0)
        if len(T[0])>0:
            Poss.extend(Pos[T[0][0]:-1])
            hs.extend(h[T[0][0]:])
    placefield = [placefield_target(pos).data.numpy() for pos in Poss]
    predict = [(torch.from_numpy(h).matmul(game.net.h2p2) + game.net.bp2) for h in hs]
#     print ('mse', np.linalg.norm(np.array(placefield) - np.array(predict)))
    def probs(field):
        prob = np.exp(-beta * field.ravel())/np.sum(np.exp(-beta * field.ravel()))
        return prob
    def probs_tensor(field):
        prob = F.softmax(-beta * field.view(-1))
        return prob
    Prob = np.array([probs(f) for f in placefield])
    Prob_p = np.array([probs_tensor(f).data.numpy() for f in predict])
    Entropy.append(-np.mean(Prob * np.log(Prob_p + 1e-5)))
    Entropy_ref.append(-np.mean(Prob * np.log(Prob + 1e-5)))

# %%
plt.plot(Entropy)
plt.plot(Entropy_ref)

# %%
Entropy = []
Entropy_ref = []
for iters, trial in enumerate(np.arange(0, 5, 1)):
    beta = 9 * 1e-2 
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.5), (0.5, 0.5)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    Poss = []
    hs = []
    for i in range(10):
        Pos,h, dh, a, s, reward = trajectory(game, pos0 = (np.random.randint(2, 17), np.random.randint(2, 17)), epsilon=0.5)
        det = np.sum(s[1:]- s[:-1], axis = 1)
        T = np.where(det!=0)
        if len(T[0])>0:
            Poss.extend(Pos[T[0][0]:-1])
            hs.extend(h[T[0][0]:])
    placefield = [placefield_target(pos).data.numpy() for pos in Poss]
    predict = [(torch.from_numpy(h).matmul(game.net.h2p3) + game.net.bp3) for h in hs]
#     print ('mse', np.linalg.norm(np.array(placefield) - np.array(predict)))
    def probs(field):
        prob = np.exp(-beta * field.ravel())/np.sum(np.exp(-beta * field.ravel()))
        return prob
    def probs_tensor(field):
        prob = F.softmax(-beta * field.view(-1))
        return prob
    Prob = np.array([probs(f) for f in placefield])
    Prob_p = np.array([probs_tensor(f).data.numpy() for f in predict])
    Entropy.append(-np.mean(Prob * np.log(Prob_p + 1e-5)))
    Entropy_ref.append(-np.mean(Prob * np.log(Prob + 1e-5)))

# %%
plt.plot(Entropy)
plt.plot(Entropy_ref)

# %%
trial = 6
game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.5), (0.5, 0.5)],  alpha = 0.5, input_type = 0)
game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
Poss = []
hs = []
for i in range(1):
    Pos,h, dh, a, s, reward = trajectory(game, pos0 = (5, 2), epsilon=1)
    Poss.extend(Pos[:-1])
    hs.extend(h)
    placefield = [placefield_target(pos).data.numpy() for pos in Poss]
    predict = [(torch.from_numpy(h).matmul(game.net.h2p1) + game.net.bp1).data.numpy() for h in hs]
beta = 1e-2
for i in range(30):
    plt.figure()
    prob = np.exp(-beta * placefield[4 * i + 1].ravel())/np.sum(np.exp(-beta * placefield[4 * i + 1].ravel()))
    plt.plot(prob, 'k')
    prob_p = np.exp(-beta * predict[4 * i + 1].ravel())/np.sum(np.exp(-beta * predict[4 * i + 1].ravel()))
    plt.plot(prob_p, 'r')
    print ('entropy', -np.sum(prob * np.log(prob_p + 1e-5)))
# Out:
# entropy 3.7120461
# entropy 3.769534
# entropy 3.7578127
# entropy 3.7732453
# entropy 3.786972
# entropy 3.7869732
# entropy 3.7869732
# entropy 3.7869732
# entropy 3.80366
# entropy 3.8110676
# entropy 3.8367682
# entropy 3.814989
# entropy 3.814989
# entropy 3.8280256
# entropy 3.8593016
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-5e9101b7728c> in <module>
#      13 for i in range(30):
#      14     plt.figure()
# ---> 15     prob = np.exp(-beta * placefield[4 * i + 1].ravel())/np.sum(np.exp(-beta * placefield[4 * i + 1].ravel()))
#      16     plt.plot(prob, 'k')
#      17     prob_p = np.exp(-beta * predict[4 * i + 1].ravel())/np.sum(np.exp(-beta * predict[4 * i + 1].ravel()))
#
# IndexError: list index out of range

# %% [markdown]
# ## Trends of weights change

# %%
for trial in np.arange(0, 5, 1):
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    plt.figure()
    sns.distplot(game.net.state_dict()['h2p1'].data.numpy().ravel())

# %%
for trial in np.arange(0, 400, 40):
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    plt.figure()
    sns.distplot(game.net.state_dict()['h2p2'].data.numpy().ravel())

# %%
for trial in np.arange(0, 400, 40):
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    plt.figure()
    sns.distplot(game.net.state_dict()['h2p3'].data.numpy().ravel())

# %%
for trial in np.arange(0, 400, 40):
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    plt.figure()
    sns.distplot(game.net.state_dict()['bp3'].data.numpy().ravel())

# %%
for trial in np.arange(0,160,20):
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    Pos,hs, dh, a, s, reward = trajectory(game, pos0 = (4, 2), epsilon=1, limit_set = 8)
    plt.figure()
    for i in range(512):
        plt.scatter(np.std(hs[:, i]), np.mean(hs[:, i]))
    print (np.where(np.std(hs, axis = 0)<0.1))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([ 10,  45,  59,  68, 169, 188, 208, 211, 279, 323, 373, 388, 396,
#        439, 474, 505]),)
# (array([], dtype=int64),)
# (array([  0,   3,   4,  10,  14,  21,  32,  34,  49,  59,  82,  98, 107,
#        117, 158, 164, 172, 174, 181, 182, 208, 209, 220, 223, 231, 235,
#        238, 270, 278, 279, 285, 299, 302, 306, 313, 318, 322, 324, 341,
#        343, 344, 354, 366, 371, 374, 413, 418, 434, 450, 452, 453, 456, 459]),)
# (array([103]),)
# (array([208, 277]),)
# (array([104, 160, 165, 186, 188, 277, 333, 366, 421, 428, 485]),)

# %% [markdown]
# ## Spectre & Low rank analysis

# %%
dWs = []
for iters, trial in enumerate(np.arange(0, 301, 100)):
    game = ValueMaxGame(grid_size = (15, 15), holes = 0, random_seed = 4 , set_reward = [(0.5, 0.25), (0.5, 0.75)],  alpha = 0.5, input_type = 0)
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    game.net.h2o = nn.Parameter(torch.randn(512, 4) * 1 * np.sqrt(2.0/(512+4)))
    if iters == 0:
        W0 = game.net.h2h 
    W = game.net.h2h 
    dWs.append(W - W0)
    Weff = game.net.h2h + game.net.h2o.matmul(game.net.a2h)
    plt.figure()
    plt.scatter (W.eig()[0][:,0].data.numpy(), W.eig()[0][:,1].data.numpy(), label = trial, color = 'r')
#     plt.figure()
#     plt.scatter (Weff.eig()[0][:,0].data.numpy(), Weff.eig()[0][:,1].data.numpy(), label = trial, color = 'b')
    
#     plt.legend()
#     plt.xlim(-2, 2)
#     plt.ylim(-3, 3)

    plt.xlabel('eigen real')
    plt.ylabel('eigen img')
    plt.savefig('eigen{}'.format(trial))
#     print (Weff)

# %%
trial = np.arange(0, 301, 100)
for dW, trial in zip(dWs[1:], trial[1:]):
    dW = dW.data.numpy()
    dW_shuffle = np.random.permutation(dW.ravel()).reshape(512, 512)
    u, s, vh = np.linalg.svd(dW)
    u_shuffle, s_shuffle, vh_shuffle = np.linalg.svd(dW_shuffle)

    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)))
    for i in range(4):
        wah0 = game.net.state_dict()['a2h'].data.numpy()[i] 
        theta1 = np.dot(wah0, vh[2])/(np.linalg.norm(vh[2]) * np.linalg.norm(wah0))
        theta2 = np.dot(wah0, u[2])/(np.linalg.norm(u[2]) * np.linalg.norm(wah0))
        theta3 = np.dot(u[2], vh[2])/(np.linalg.norm(u[2]) * np.linalg.norm(vh[2]))
        print (trial, theta1, theta2, theta3)
    if trial == 300:
        ax = subplot(1, 1, 1)
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        plt.plot(s[:100],'r.')
        plt.plot(s_shuffle[:100],'r--')
        plt.xticks(size = 15)
        plt.yticks([0, 2, 4, 6, 8], size = 15)
# Out:
# 100 0.39087936 -0.0077583306 -0.023033777
# 100 -0.35095876 -0.0049547525 -0.023033777
# 100 -0.36860266 0.06619975 -0.023033777
# 100 0.41238436 0.031995893 -0.023033777
# 200 -0.1817752 -0.08043407 0.03723478
# 200 0.32433614 -0.0031942604 0.03723478
# 200 0.22594944 0.044715352 0.03723478
# 200 -0.27185404 0.016290054 0.03723478
# 300 -0.03550171 0.022606151 0.036227085
# 300 0.18898071 0.07466147 0.036227085
# 300 0.094034076 0.04272938 0.036227085
# 300 -0.1287412 0.0033626016 0.036227085

# %%
# ax = subplot(1, 1, 1)
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
for r in np.arange(100):
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(300)))
    theta = 0
    for i in range(4):
        wah0 = game.net.state_dict()['a2h'].data.numpy()[i] 
        theta1 = np.dot(wah0, vh[r])/(np.linalg.norm(vh[r]) * np.linalg.norm(wah0))
        theta2 = np.dot(wah0, u[r])/(np.linalg.norm(u[r]) * np.linalg.norm(wah0))
        theta3 = np.dot(u[0], vh[r])/(np.linalg.norm(u[r]) * np.linalg.norm(vh[0]))
        theta += np.abs(theta1)
    ax = subplot(1, 1, 1)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.scatter(r, theta/4, color = 'r')
#         print (trial, theta1, theta2, theta3)
plt.xticks(size = 15)
plt.yticks([0, 0.1, 0.2, 0.3], size = 15)
# plt.title('wah pre1')
# Out:
# ([<matplotlib.axis.YTick at 0x7f8180038a90>,
#   <matplotlib.axis.YTick at 0x7f8180038e10>,
#   <matplotlib.axis.YTick at 0x7f816f8d8550>,
#   <matplotlib.axis.YTick at 0x7f8180059588>],
#  <a list of 4 Text yticklabel objects>)

# %%
# ax = subplot(1, 1, 1)
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
for r in np.arange(100):
    game.net.load_state_dict(torch.load('weights_cpu/rnn_1515tanh512_checkpoint{}'.format(300)))
    theta = np.zeros(9)
    for i in range(9):
        wah0 = game.net.state_dict()['i2h'].data.numpy()[i] 
        theta1 = np.dot(wah0, vh[r])/(np.linalg.norm(vh[r]) * np.linalg.norm(wah0))
        theta2 = np.dot(wah0, u[r])/(np.linalg.norm(u[r]) * np.linalg.norm(wah0))
        theta3 = np.dot(u[0], vh[r])/(np.linalg.norm(u[r]) * np.linalg.norm(vh[0]))
        theta [i] = np.abs(theta1)
    ax = subplot(1, 1, 1)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.scatter(r, np.mean(theta), color = 'r')
#         print (trial, theta1, theta2, theta3)
plt.xticks(size = 15)
plt.yticks([0, 0.1, 0.2, 0.3], size = 15)
# Out:
# ([<matplotlib.axis.YTick at 0x7f81800f4898>,
#   <matplotlib.axis.YTick at 0x7f816f7b2da0>,
#   <matplotlib.axis.YTick at 0x7f81801a2c18>,
#   <matplotlib.axis.YTick at 0x7f81801fe240>],
#  <a list of 4 Text yticklabel objects>)

# %% [markdown]
# If look carefully, the slow timescale here is a very long transient,  it will not return to baseline in a very long run of game, that is different from gru, which maintains a baseline.  If the system is a true integrator,  it should not loose the baseline, because there is no concept of return in this case.
#
# The very slow timescale could make the system harder to reset, except I use a strong input.  So reset upon input and remember is always contradictory.  If I design a task also need to pay attention to fast timescale , this will fail more throughly

# %% [markdown]
# # Timescale, Spatial Information & Performance

# %% [markdown]
# **There is change associate with the pretraining, but if coupling all factors and use short stimlus pulses, there is no big effect**
#
# **charaterize the system by timescale in this case, and input - output correlation with random action, use these two parameters to predict learning**
#
# **Another approach is the random readout compare,  the specific readout is related to one network, if we look at things statistically, something related to Whh will truly reveal.  The distribution also permits us to give continouse number as probability of bi-stability**
#
# **Characterize the limit cycle by period and shape/complexity/dimension of wave**

# %%
def findslowpoint(weight, hidden0, stim = torch.zeros(1, 9) , action = 4):
    for i in range(int(3 * 1e3)):
        hidden0 = Variable(hidden0,requires_grad=True)
        velocity = fixpoints(weight, hidden0, stim = stim, action = action)
    #     print (hidden0.requires_grad)
        velocity.backward()
    #     print ('grad0', hidden0.grad[0][0])
        hidden0 = torch.add(hidden0, -1e-2 * (hidden0.grad))
        hidden0 = Variable(hidden0,requires_grad=True)
    return hidden0, velocity
    #     print ('grad', hidden0.grad)

# %%
weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(0)
pca = PCA(weight)
pca.pca(T_duration = 5)
context = pca.game.placefield((9, 5))
pca.Dynamics(Actions = 10 * [4], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
             readout_random = False, open_loop = True, context = context)
Hiddens0 = []
for i in range(4):
    for j in range(10):
        Hiddens0.append(pca.Hiddens[i, j, -1])

Hidden_echo = []
Velocity_echo = []
for hidden0 in Hiddens0:
    hidden0 = torch.from_numpy(hidden0).type(torch.FloatTensor)
#     hidden0 = torch.randn(1, 512, requires_grad = True)
    hidden, velocity = findslowpoint(weight, hidden0)
    Hidden_echo.append(hidden)
    Velocity_echo.append(velocity)

# %%
np.save('fixpoints_echo', Hidden_echo)
np.save('velocity_echo', Velocity_echo)

# %%
pca = PCA(weight)
pca.pca(T_duration = 5)
color = ['r', 'g', 'b', 'm']
for i, hidden in enumerate(Hidden_echo):
    plt.figure(0)
    plt.scatter(hidden.data.numpy() @ pca.vect[0], hidden.data.numpy() @ pca.vect[1], color = color[i//10])

# %%
weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(270)
pca = PCA(weight)
pca.pca(T_duration = 5)
context = pca.game.placefield((9, 5))
pca.Dynamics(Actions = 100 * [4], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
             readout_random = False, open_loop = True, context = context)
Hiddens0 = []
for i in range(4):
    for j in range(100):
        Hiddens0.append(pca.Hiddens[i, j, -1])

Hidden_270 = []
Velocity_270 = []
for hidden0 in Hiddens0:
    hidden0 = torch.from_numpy(hidden0).type(torch.FloatTensor)
#     hidden0 = torch.randn(1, 512, requires_grad = True)
    hidden, velocity = findslowpoint(weight, hidden0)
    Hidden_270.append(hidden)
    Velocity_270.append(velocity)

# %%
# preprare initial hidden states for all stimuli  
weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(300)
pca = PCA(weight)
pca.pca(T_duration = 5)
context = pca.game.placefield((9, 5))
pca.Dynamics(Actions = 100 * [4], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
             readout_random = False, open_loop = True, context = context)
# long dynamics for different stimulus

# %%
Hiddens0 = []
for i in range(4):
    for j in range(100):
        Hiddens0.append(pca.Hiddens[i, j, -1])

# %%
weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(300)
Hidden300 = []
for hidden0 in Hiddens0:
    hidden0 = torch.from_numpy(hidden0).type(torch.FloatTensor)
#     hidden0 = torch.randn(1, 512, requires_grad = True)
    hidden = findslowpoint(weight, hidden0)
    Hidden300.append(hidden)
# Out:
# v tensor(0.2400)
# v tensor(1.00000e-02 *
#        5.6206)
# v tensor(1.00000e-02 *
#        5.4542)
# v tensor(0.2797)
# v tensor(1.00000e-02 *
#        6.8147)
# v tensor(1.00000e-02 *
#        6.4020)
# v tensor(0.7483)
# v tensor(0.1563)
# v tensor(0.1431)
# v tensor(0.1199)
# v tensor(1.00000e-02 *
#        5.0740)
# v tensor(1.00000e-02 *
#        5.0806)
# v tensor(0.1782)
# v tensor(1.00000e-02 *
#        5.0456)
# v tensor(1.00000e-02 *
#        5.0525)
# v tensor(0.4583)
# v tensor(0.1088)
# v tensor(0.1017)
# v tensor(0.2002)
# v tensor(1.00000e-02 *
#        4.9217)
# v tensor(1.00000e-02 *
#        4.9204)
# v tensor(1.00000e-02 *
#        8.0958)
# v tensor(1.00000e-02 *
#        5.0789)
# v tensor(1.00000e-02 *
#        5.0880)
# v tensor(0.1387)
# v tensor(1.00000e-02 *
#        5.0665)
# v tensor(1.00000e-02 *
#        5.0727)
# v tensor(0.2051)
# v tensor(1.00000e-02 *
#        5.0400)
# v tensor(1.00000e-02 *
#        5.0362)
# v tensor(0.1831)
# v tensor(1.00000e-02 *
#        4.9921)
# v tensor(1.00000e-02 *
#        5.0102)
# v tensor(0.3355)
# v tensor(1.00000e-02 *
#        8.2989)
# v tensor(1.00000e-02 *
#        7.8499)
# v tensor(0.2618)
# v tensor(1.00000e-02 *
#        6.4351)
# v tensor(1.00000e-02 *
#        6.3573)
# v tensor(0.1384)
# v tensor(1.00000e-02 *
#        5.0370)
# v tensor(1.00000e-02 *
#        5.0518)
# v tensor(0.7237)
# v tensor(0.1518)
# v tensor(0.1395)
# v tensor(0.4662)
# v tensor(0.1101)
# v tensor(0.1032)
# v tensor(0.1222)
# v tensor(1.00000e-02 *
#        5.0402)
# v tensor(1.00000e-02 *
#        5.0497)
# v tensor(0.1774)
# v tensor(1.00000e-02 *
#        4.9988)
# v tensor(1.00000e-02 *
#        5.0177)
# v tensor(0.2759)
# v tensor(1.00000e-02 *
#        6.7517)
# v tensor(1.00000e-02 *
#        6.7277)
# v tensor(0.4266)
# v tensor(0.1031)
# v tensor(1.00000e-02 *
#        9.6666)
# v tensor(1.00000e-02 *
#        8.6593)
# v tensor(1.00000e-02 *
#        5.0767)
# v tensor(1.00000e-02 *
#        5.0870)
# v tensor(0.2499)
# v tensor(1.00000e-02 *
#        6.1861)
# v tensor(1.00000e-02 *
#        6.0516)
# v tensor(0.2178)
# v tensor(1.00000e-02 *
#        5.1405)
# v tensor(1.00000e-02 *
#        5.0232)
# v tensor(1.00000e-02 *
#        8.0458)
# v tensor(1.00000e-02 *
#        5.0752)
# v tensor(1.00000e-02 *
#        5.0805)
# v tensor(0.2014)
# v tensor(1.00000e-02 *
#        4.9738)
# v tensor(1.00000e-02 *
#        4.9963)
# v tensor(1.00000e-02 *
#        8.8027)
# v tensor(1.00000e-02 *
#        5.0755)
# v tensor(1.00000e-02 *
#        5.0858)
# v tensor(1.00000e-02 *
#        8.4958)
# v tensor(1.00000e-02 *
#        5.0759)
# v tensor(1.00000e-02 *
#        5.0856)
# v tensor(0.2283)
# v tensor(1.00000e-02 *
#        5.7446)
# v tensor(1.00000e-02 *
#        5.4960)
# v tensor(1.00000e-02 *
#        9.2909)
# v tensor(1.00000e-02 *
#        5.0767)
# v tensor(1.00000e-02 *
#        5.0785)
# v tensor(0.7058)
# v tensor(0.1492)
# v tensor(0.1367)
# v tensor(0.1104)
# v tensor(1.00000e-02 *
#        5.0781)
# v tensor(1.00000e-02 *
#        5.0845)
# v tensor(0.8112)
# v tensor(0.1660)
# v tensor(0.1531)
# v tensor(0.1736)
# v tensor(1.00000e-02 *
#        5.0455)
# v tensor(1.00000e-02 *
#        5.0543)
# v tensor(0.2728)
# v tensor(1.00000e-02 *
#        6.5511)
# v tensor(1.00000e-02 *
#        6.5012)
# v tensor(0.2392)
# v tensor(1.00000e-02 *
#        5.8094)
# v tensor(1.00000e-02 *
#        5.6232)
# v tensor(0.4322)
# v tensor(0.1043)
# v tensor(1.00000e-02 *
#        9.7153)
# v tensor(0.2102)
# v tensor(1.00000e-02 *
#        4.8272)
# v tensor(1.00000e-02 *
#        4.9872)
# v tensor(0.1345)
# v tensor(1.00000e-02 *
#        5.0676)
# v tensor(1.00000e-02 *
#        5.0745)
# v tensor(0.5187)
# v tensor(0.1071)
# v tensor(1.00000e-02 *
#        8.5364)
# v tensor(0.1161)
# v tensor(1.00000e-02 *
#        5.0764)
# v tensor(1.00000e-02 *
#        5.0824)
# v tensor(0.2692)
# v tensor(1.00000e-02 *
#        6.5290)
# v tensor(1.00000e-02 *
#        6.1061)
# v tensor(0.4644)
# v tensor(0.1101)
# v tensor(0.1021)
# v tensor(0.1539)
# v tensor(1.00000e-02 *
#        5.0178)
# v tensor(1.00000e-02 *
#        5.0318)
# v tensor(0.2764)
# v tensor(1.00000e-02 *
#        6.7633)
# v tensor(1.00000e-02 *
#        6.7396)
# v tensor(0.7288)
# v tensor(0.1529)
# v tensor(0.1402)
# v tensor(1.00000e-02 *
#        6.2470)
# v tensor(1.00000e-02 *
#        5.0745)
# v tensor(1.00000e-02 *
#        5.0756)
# v tensor(0.1653)
# v tensor(1.00000e-02 *
#        5.0485)
# v tensor(1.00000e-02 *
#        5.0556)
# v tensor(0.2714)
# v tensor(1.00000e-02 *
#        6.6093)
# v tensor(1.00000e-02 *
#        6.2356)
# v tensor(0.1471)
# v tensor(1.00000e-02 *
#        5.0613)
# v tensor(1.00000e-02 *
#        5.0687)
# v tensor(0.1242)
# v tensor(1.00000e-02 *
#        5.0786)
# v tensor(1.00000e-02 *
#        5.0824)
# v tensor(0.3752)
# v tensor(1.00000e-02 *
#        7.4428)
# v tensor(1.00000e-02 *
#        4.8326)
# v tensor(0.7987)
# v tensor(0.1633)
# v tensor(0.1507)
# v tensor(0.2778)
# v tensor(1.00000e-02 *
#        6.7360)
# v tensor(1.00000e-02 *
#        6.7146)
# v tensor(0.6328)
# v tensor(0.1377)
# v tensor(0.1260)
# v tensor(1.00000e-02 *
#        9.5403)
# v tensor(1.00000e-02 *
#        5.0698)
# v tensor(1.00000e-02 *
#        5.0804)
# v tensor(0.2438)
# v tensor(1.00000e-02 *
#        6.1034)
# v tensor(1.00000e-02 *
#        5.9335)
# v tensor(0.2812)
# v tensor(1.00000e-02 *
#        6.8471)
# v tensor(1.00000e-02 *
#        6.4212)
# v tensor(0.8166)
# v tensor(0.1679)
# v tensor(0.1541)
# v tensor(0.3290)
# v tensor(1.00000e-02 *
#        8.1434)
# v tensor(1.00000e-02 *
#        7.7420)
# v tensor(0.1694)
# v tensor(1.00000e-02 *
#        5.0084)
# v tensor(1.00000e-02 *
#        5.0267)
# v tensor(1.00000e-02 *
#        8.7179)
# v tensor(1.00000e-02 *
#        5.0732)
# v tensor(1.00000e-02 *
#        5.0826)
# v tensor(0.5370)
# v tensor(0.1223)
# v tensor(0.1126)
# v tensor(1.00000e-02 *
#        5.8218)
# v tensor(1.00000e-02 *
#        5.0779)
# v tensor(1.00000e-02 *
#        5.0800)
# v tensor(1.00000e-02 *
#        9.8711)
# v tensor(1.00000e-02 *
#        5.0694)
# v tensor(1.00000e-02 *
#        5.0731)
# v tensor(0.5371)
# v tensor(0.1109)
# v tensor(1.00000e-02 *
#        8.9978)
# v tensor(0.2665)
# v tensor(1.00000e-02 *
#        6.5258)
# v tensor(1.00000e-02 *
#        6.4707)
# v tensor(0.3630)
# v tensor(1.00000e-02 *
#        8.9732)
# v tensor(1.00000e-02 *
#        8.4746)
# v tensor(0.6467)
# v tensor(0.1398)
# v tensor(0.1280)
# v tensor(0.2789)
# v tensor(1.00000e-02 *
#        6.7826)
# v tensor(1.00000e-02 *
#        6.3486)
# v tensor(0.2529)
# v tensor(1.00000e-02 *
#        6.0442)
# v tensor(1.00000e-02 *
#        5.5736)
# v tensor(0.2471)
# v tensor(1.00000e-02 *
#        5.8905)
# v tensor(1.00000e-02 *
#        5.7351)
# v tensor(0.3142)
# v tensor(1.00000e-02 *
#        7.7409)
# v tensor(1.00000e-02 *
#        7.3092)
# v tensor(0.5185)
# v tensor(0.1193)
# v tensor(0.1100)
# v tensor(0.2376)
# v tensor(1.00000e-02 *
#        5.9743)
# v tensor(1.00000e-02 *
#        5.7709)
# v tensor(0.2149)
# v tensor(1.00000e-02 *
#        5.3968)
# v tensor(1.00000e-02 *
#        5.0850)
# v tensor(0.1444)
# v tensor(1.00000e-02 *
#        5.0266)
# v tensor(1.00000e-02 *
#        5.0394)
# v tensor(0.3927)
# v tensor(1.00000e-02 *
#        9.6311)
# v tensor(1.00000e-02 *
#        9.0637)
# v tensor(0.3409)
# v tensor(1.00000e-02 *
#        8.4313)
# v tensor(1.00000e-02 *
#        7.9638)
# v tensor(1.00000e-02 *
#        3.5577)
# v tensor(1.00000e-02 *
#        5.0770)
# v tensor(1.00000e-02 *
#        5.0757)
# v tensor(0.1768)
# v tensor(1.00000e-02 *
#        5.0020)
# v tensor(1.00000e-02 *
#        5.0214)
# v tensor(0.5872)
# v tensor(0.1299)
# v tensor(0.1200)
# v tensor(0.2471)
# v tensor(1.00000e-02 *
#        5.9950)
# v tensor(1.00000e-02 *
#        5.8467)
# v tensor(0.5248)
# v tensor(0.1200)
# v tensor(0.1113)
# v tensor(0.8067)
# v tensor(0.1651)
# v tensor(0.1523)
# v tensor(0.1796)
# v tensor(1.00000e-02 *
#        5.0415)
# v tensor(1.00000e-02 *
#        5.0489)
# v tensor(0.2618)
# v tensor(1.00000e-02 *
#        6.2472)
# v tensor(1.00000e-02 *
#        6.1466)
# v tensor(0.1278)
# v tensor(1.00000e-02 *
#        5.0466)
# v tensor(1.00000e-02 *
#        5.0603)
# v tensor(0.2362)
# v tensor(1.00000e-02 *
#        5.7264)
# v tensor(1.00000e-02 *
#        5.5254)
# v tensor(0.1305)
# v tensor(1.00000e-02 *
#        5.0683)
# v tensor(1.00000e-02 *
#        5.0763)
# v tensor(0.2617)
# v tensor(1.00000e-02 *
#        6.4838)
# v tensor(1.00000e-02 *
#        6.4020)
# v tensor(0.2834)
# v tensor(1.00000e-02 *
#        5.1704)
# v tensor(1.00000e-02 *
#        4.9716)
# v tensor(0.2430)
# v tensor(1.00000e-02 *
#        5.8448)
# v tensor(1.00000e-02 *
#        5.4362)
# v tensor(1.00000e-02 *
#        7.9518)
# v tensor(1.00000e-02 *
#        5.0772)
# v tensor(1.00000e-02 *
#        5.0784)
# v tensor(0.2265)
# v tensor(1.00000e-02 *
#        5.2856)
# v tensor(1.00000e-02 *
#        4.9673)
# v tensor(0.5422)
# v tensor(0.1228)
# v tensor(0.1137)
# v tensor(0.1382)
# v tensor(1.00000e-02 *
#        5.0650)
# v tensor(1.00000e-02 *
#        5.0728)
# v tensor(0.1240)
# v tensor(1.00000e-02 *
#        5.0390)
# v tensor(1.00000e-02 *
#        5.0483)
# v tensor(0.2056)
# v tensor(1.00000e-02 *
#        4.9655)
# v tensor(1.00000e-02 *
#        4.9891)
# v tensor(0.2769)
# v tensor(1.00000e-02 *
#        6.7298)
# v tensor(1.00000e-02 *
#        6.2952)
# v tensor(0.1369)
# v tensor(1.00000e-02 *
#        5.0333)
# v tensor(1.00000e-02 *
#        5.0450)
# v tensor(0.2040)
# v tensor(1.00000e-02 *
#        6.2042)
# v tensor(1.00000e-02 *
#        5.6709)
# v tensor(0.2589)
# v tensor(1.00000e-02 *
#        7.7272)
# v tensor(1.00000e-02 *
#        7.0785)
# v tensor(0.1397)
# v tensor(1.00000e-02 *
#        4.8845)
# v tensor(1.00000e-02 *
#        4.8882)
# v tensor(0.2088)
# v tensor(1.00000e-02 *
#        6.1469)
# v tensor(1.00000e-02 *
#        5.5189)
# v tensor(0.1794)
# v tensor(1.00000e-02 *
#        5.3338)
# v tensor(1.00000e-02 *
#        4.8207)
# v tensor(0.1689)
# v tensor(1.00000e-02 *
#        5.2207)
# v tensor(1.00000e-02 *
#        4.8637)
# v tensor(0.2294)
# v tensor(1.00000e-02 *
#        6.7056)
# v tensor(1.00000e-02 *
#        6.0102)
# v tensor(0.5543)
# v tensor(0.1708)
# v tensor(0.1691)
# v tensor(1.00000e-02 *
#        6.6625)
# v tensor(1.00000e-02 *
#        4.8227)
# v tensor(1.00000e-02 *
#        4.8282)
# v tensor(1.00000e-02 *
#        4.6565)
# v tensor(1.00000e-02 *
#        4.2474)
# v tensor(1.00000e-02 *
#        4.0178)
# v tensor(0.5878)
# v tensor(0.1381)
# v tensor(0.1376)
# v tensor(0.1286)
# v tensor(1.00000e-02 *
#        4.8222)
# v tensor(1.00000e-02 *
#        4.8303)
# v tensor(0.3681)
# v tensor(1.00000e-02 *
#        7.5214)
# v tensor(1.00000e-02 *
#        6.6940)
# v tensor(1.00000e-02 *
#        5.1743)
# v tensor(1.00000e-02 *
#        4.8837)
# v tensor(1.00000e-02 *
#        4.8944)
# v tensor(0.1485)
# v tensor(1.00000e-02 *
#        4.9767)
# v tensor(1.00000e-02 *
#        4.9799)
# v tensor(0.1192)
# v tensor(1.00000e-02 *
#        4.9387)
# v tensor(1.00000e-02 *
#        4.9368)
# v tensor(0.3354)
# v tensor(1.00000e-02 *
#        9.5999)
# v tensor(1.00000e-02 *
#        8.7448)
# v tensor(0.1137)
# v tensor(1.00000e-02 *
#        4.8626)
# v tensor(1.00000e-02 *
#        4.8630)
# v tensor(1.00000e-02 *
#        8.4240)
# v tensor(1.00000e-02 *
#        4.8350)
# v tensor(1.00000e-02 *
#        4.8333)
# v tensor(0.2021)
# v tensor(1.00000e-02 *
#        5.8974)
# v tensor(1.00000e-02 *
#        5.2642)
# v tensor(0.1536)
# v tensor(1.00000e-02 *
#        4.9390)
# v tensor(1.00000e-02 *
#        4.9375)
# v tensor(0.1902)
# v tensor(1.00000e-02 *
#        5.8178)
# v tensor(1.00000e-02 *
#        5.3005)
# v tensor(0.1736)
# v tensor(1.00000e-02 *
#        5.0040)
# v tensor(1.00000e-02 *
#        4.9268)
# v tensor(1.00000e-02 *
#        6.4730)
# v tensor(1.00000e-02 *
#        4.8701)
# v tensor(1.00000e-02 *
#        4.8728)
# v tensor(0.1795)
# v tensor(1.00000e-02 *
#        5.0881)
# v tensor(1.00000e-02 *
#        4.8040)
# v tensor(0.4892)
# v tensor(0.1149)
# v tensor(0.1083)
# v tensor(0.3139)
# v tensor(1.00000e-02 *
#        7.0098)
# v tensor(1.00000e-02 *
#        6.4549)
# v tensor(0.1789)
# v tensor(1.00000e-02 *
#        5.3462)
# v tensor(1.00000e-02 *
#        4.8407)
# v tensor(0.2500)
# v tensor(1.00000e-02 *
#        7.3281)
# v tensor(1.00000e-02 *
#        6.6073)
# v tensor(0.2351)
# v tensor(1.00000e-02 *
#        6.9782)
# v tensor(1.00000e-02 *
#        6.3195)
# v tensor(0.2118)
# v tensor(1.00000e-02 *
#        6.1455)
# v tensor(1.00000e-02 *
#        5.5191)
# v tensor(0.1454)
# v tensor(1.00000e-02 *
#        4.8736)
# v tensor(1.00000e-02 *
#        4.8805)
# v tensor(0.1160)
# v tensor(1.00000e-02 *
#        4.8376)
# v tensor(1.00000e-02 *
#        4.8410)
# v tensor(1.00000e-02 *
#        7.9473)
# v tensor(1.00000e-02 *
#        4.8048)
# v tensor(1.00000e-02 *
#        4.8115)
# v tensor(0.1444)
# v tensor(1.00000e-02 *
#        5.0042)
# v tensor(1.00000e-02 *
#        5.0134)
# v tensor(0.1811)
# v tensor(1.00000e-02 *
#        5.6126)
# v tensor(1.00000e-02 *
#        5.1826)
# v tensor(0.4409)
# v tensor(0.1309)
# v tensor(0.1272)
# v tensor(0.1977)
# v tensor(1.00000e-02 *
#        6.0603)
# v tensor(1.00000e-02 *
#        5.5596)
# v tensor(0.1408)
# v tensor(1.00000e-02 *
#        4.9854)
# v tensor(1.00000e-02 *
#        4.9953)
# v tensor(0.2328)
# v tensor(1.00000e-02 *
#        6.8975)
# v tensor(1.00000e-02 *
#        6.2481)
# v tensor(0.1590)
# v tensor(1.00000e-02 *
#        4.8642)
# v tensor(1.00000e-02 *
#        4.8746)
# v tensor(0.1596)
# v tensor(1.00000e-02 *
#        4.7540)
# v tensor(1.00000e-02 *
#        4.8545)
# v tensor(0.1005)
# v tensor(1.00000e-02 *
#        4.8384)
# v tensor(1.00000e-02 *
#        4.8389)
# v tensor(0.3043)
# v tensor(1.00000e-02 *
#        8.6606)
# v tensor(1.00000e-02 *
#        7.9718)
# v tensor(0.2506)
# v tensor(1.00000e-02 *
#        7.0704)
# v tensor(1.00000e-02 *
#        6.4021)
# v tensor(0.1822)
# v tensor(1.00000e-02 *
#        5.6023)
# v tensor(1.00000e-02 *
#        5.1675)
# v tensor(0.6966)
# v tensor(0.1748)
# v tensor(0.1566)
# v tensor(0.1774)
# v tensor(1.00000e-02 *
#        5.0637)
# v tensor(1.00000e-02 *
#        4.8127)
# v tensor(0.1135)
# v tensor(1.00000e-02 *
#        4.7698)
# v tensor(1.00000e-02 *
#        4.7763)
# v tensor(0.2720)
# v tensor(1.00000e-02 *
#        7.0758)
# v tensor(1.00000e-02 *
#        6.5561)
# v tensor(1.00000e-02 *
#        9.4621)
# v tensor(1.00000e-02 *
#        4.8543)
# v tensor(1.00000e-02 *
#        4.8505)
# v tensor(0.1742)
# v tensor(1.00000e-02 *
#        4.8615)
# v tensor(1.00000e-02 *
#        4.7918)
# v tensor(0.1681)
# v tensor(1.00000e-02 *
#        5.0438)
# v tensor(1.00000e-02 *
#        4.8757)
# v tensor(0.2378)
# v tensor(1.00000e-02 *
#        6.7867)
# v tensor(1.00000e-02 *
#        6.0138)
# v tensor(0.1484)
# v tensor(1.00000e-02 *
#        4.8941)
# v tensor(1.00000e-02 *
#        4.9010)
# v tensor(0.1865)
# v tensor(1.00000e-02 *
#        5.3524)
# v tensor(1.00000e-02 *
#        4.6987)
# v tensor(0.1399)
# v tensor(1.00000e-02 *
#        4.8334)
# v tensor(1.00000e-02 *
#        4.8418)
# v tensor(0.1148)
# v tensor(1.00000e-02 *
#        4.8479)
# v tensor(1.00000e-02 *
#        4.8494)
# v tensor(0.5831)
# v tensor(0.1444)
# v tensor(0.1430)
# v tensor(0.2081)
# v tensor(1.00000e-02 *
#        5.4396)
# v tensor(1.00000e-02 *
#        5.0475)
# v tensor(0.1116)
# v tensor(1.00000e-02 *
#        4.8303)
# v tensor(1.00000e-02 *
#        4.8338)
# v tensor(1.00000e-02 *
#        8.7088)
# v tensor(1.00000e-02 *
#        4.8211)
# v tensor(1.00000e-02 *
#        4.8258)
# v tensor(0.1503)
# v tensor(1.00000e-02 *
#        4.9657)
# v tensor(1.00000e-02 *
#        4.9781)
# v tensor(0.2509)
# v tensor(1.00000e-02 *
#        7.4199)
# v tensor(1.00000e-02 *
#        6.7275)
# v tensor(0.1216)
# v tensor(1.00000e-02 *
#        4.8812)
# v tensor(1.00000e-02 *
#        4.8796)
# v tensor(0.1551)
# v tensor(1.00000e-02 *
#        4.9336)
# v tensor(1.00000e-02 *
#        4.9432)
# v tensor(0.1406)
# v tensor(1.00000e-02 *
#        4.8856)
# v tensor(1.00000e-02 *
#        4.8898)
# v tensor(0.3132)
# v tensor(1.00000e-02 *
#        8.6560)
# v tensor(1.00000e-02 *
#        7.5836)
# v tensor(1.00000e-02 *
#        4.5893)
# v tensor(1.00000e-02 *
#        4.8902)
# v tensor(1.00000e-02 *
#        4.8967)
# v tensor(0.5505)
# v tensor(0.1367)
# v tensor(0.1361)
# v tensor(0.3950)
# v tensor(0.1160)
# v tensor(0.1104)
# v tensor(0.5037)
# v tensor(0.1003)
# v tensor(1.00000e-02 *
#        9.8368)
# v tensor(0.1605)
# v tensor(1.00000e-02 *
#        4.7942)
# v tensor(1.00000e-02 *
#        4.8104)
# v tensor(0.1255)
# v tensor(1.00000e-02 *
#        4.8132)
# v tensor(1.00000e-02 *
#        4.8207)
# v tensor(0.1044)
# v tensor(1.00000e-02 *
#        4.7893)
# v tensor(1.00000e-02 *
#        4.7952)
# v tensor(1.00000e-02 *
#        4.6396)
# v tensor(1.00000e-02 *
#        4.9130)
# v tensor(1.00000e-02 *
#        4.9190)
# v tensor(0.1749)
# v tensor(1.00000e-02 *
#        4.8406)
# v tensor(1.00000e-02 *
#        4.8410)
# v tensor(0.2940)
# v tensor(1.00000e-02 *
#        8.7291)
# v tensor(1.00000e-02 *
#        8.0797)
# v tensor(0.1832)
# v tensor(1.00000e-02 *
#        5.0666)
# v tensor(1.00000e-02 *
#        4.7895)
# v tensor(0.1088)
# v tensor(1.00000e-02 *
#        4.7729)
# v tensor(1.00000e-02 *
#        4.7791)
# v tensor(0.1388)
# v tensor(1.00000e-02 *
#        5.0232)
# v tensor(1.00000e-02 *
#        5.0291)
# v tensor(0.1492)
# v tensor(1.00000e-02 *
#        4.8296)
# v tensor(1.00000e-02 *
#        4.8408)
# v tensor(0.1668)
# v tensor(1.00000e-02 *
#        5.1292)
# v tensor(1.00000e-02 *
#        4.9282)
# v tensor(0.1959)
# v tensor(1.00000e-02 *
#        5.9966)
# v tensor(1.00000e-02 *
#        5.4934)
# v tensor(0.3022)
# v tensor(1.00000e-02 *
#        8.9949)
# v tensor(1.00000e-02 *
#        8.3730)
# v tensor(0.1812)
# v tensor(1.00000e-02 *
#        5.5073)
# v tensor(1.00000e-02 *
#        5.0554)
# v tensor(0.2710)
# v tensor(1.00000e-02 *
#        6.4840)
# v tensor(1.00000e-02 *
#        6.0311)
# v tensor(0.1314)
# v tensor(1.00000e-02 *
#        4.8345)
# v tensor(1.00000e-02 *
#        4.8412)
# v tensor(0.1750)
# v tensor(1.00000e-02 *
#        4.8966)
# v tensor(1.00000e-02 *
#        4.7930)
# v tensor(0.1477)
# v tensor(1.00000e-02 *
#        4.9036)
# v tensor(1.00000e-02 *
#        4.9097)
# v tensor(0.3737)
# v tensor(1.00000e-02 *
#        9.7010)
# v tensor(1.00000e-02 *
#        9.2128)
# v tensor(0.1454)
# v tensor(1.00000e-02 *
#        5.0021)
# v tensor(1.00000e-02 *
#        5.0069)
# v tensor(0.1275)
# v tensor(1.00000e-02 *
#        4.9381)
# v tensor(1.00000e-02 *
#        4.9358)
# v tensor(0.1463)
# v tensor(1.00000e-02 *
#        4.8110)
# v tensor(1.00000e-02 *
#        4.8219)
# v tensor(0.1253)
# v tensor(1.00000e-02 *
#        4.8268)
# v tensor(1.00000e-02 *
#        4.8341)
# v tensor(0.5206)
# v tensor(0.1040)
# v tensor(1.00000e-02 *
#        9.9145)
# v tensor(0.5701)
# v tensor(0.1358)
# v tensor(0.1341)
# v tensor(0.1566)
# v tensor(1.00000e-02 *
#        4.8634)
# v tensor(1.00000e-02 *
#        4.8808)
# v tensor(0.1280)
# v tensor(1.00000e-02 *
#        4.8134)
# v tensor(1.00000e-02 *
#        4.8211)
# v tensor(0.4994)
# v tensor(0.1192)
# v tensor(0.1139)
# v tensor(0.4741)
# v tensor(0.1045)
# v tensor(0.1039)
# v tensor(0.5259)
# v tensor(0.1308)
# v tensor(0.1263)
# v tensor(0.2369)
# v tensor(1.00000e-02 *
#        5.6818)
# v tensor(1.00000e-02 *
#        5.4866)
# v tensor(0.1710)
# v tensor(1.00000e-02 *
#        5.0173)
# v tensor(1.00000e-02 *
#        5.0160)
# v tensor(0.1682)
# v tensor(1.00000e-02 *
#        5.0169)
# v tensor(1.00000e-02 *
#        5.0155)
# v tensor(0.5198)
# v tensor(0.1004)
# v tensor(1.00000e-02 *
#        9.8910)
# v tensor(1.00000e-02 *
#        2.1826)
# v tensor(1.00000e-02 *
#        3.9486)
# v tensor(1.00000e-02 *
#        2.4903)
# v tensor(1.00000e-02 *
#        3.3422)
# v tensor(1.00000e-02 *
#        4.8223)
# v tensor(1.00000e-02 *
#        4.8130)
# v tensor(0.3990)
# v tensor(1.00000e-02 *
#        9.2548)
# v tensor(1.00000e-02 *
#        9.0683)
# v tensor(0.5141)
# v tensor(0.1104)
# v tensor(0.1078)
# v tensor(0.5050)
# v tensor(0.1045)
# v tensor(0.1033)
# v tensor(0.4757)
# v tensor(0.1046)
# v tensor(0.1040)
# v tensor(1.00000e-02 *
#        7.7497)
# v tensor(1.00000e-02 *
#        4.9431)
# v tensor(1.00000e-02 *
#        4.9394)
# v tensor(0.5170)
# v tensor(0.1032)
# v tensor(0.1017)
# v tensor(0.4730)
# v tensor(0.1044)
# v tensor(0.1038)
# v tensor(0.2477)
# v tensor(1.00000e-02 *
#        5.5505)
# v tensor(1.00000e-02 *
#        5.3537)
# v tensor(0.2873)
# v tensor(1.00000e-02 *
#        6.5930)
# v tensor(1.00000e-02 *
#        6.3518)
# v tensor(0.5186)
# v tensor(0.1114)
# v tensor(0.1086)
# v tensor(0.5189)
# v tensor(1.00000e-02 *
#        9.8491)
# v tensor(1.00000e-02 *
#        9.7288)
# v tensor(0.4707)
# v tensor(0.1042)
# v tensor(0.1036)
# v tensor(0.5052)
# v tensor(0.1137)
# v tensor(0.1108)
# v tensor(0.4559)
# v tensor(0.1025)
# v tensor(0.1018)
# v tensor(0.1698)
# v tensor(1.00000e-02 *
#        5.0171)
# v tensor(1.00000e-02 *
#        5.0158)
# v tensor(0.3406)
# v tensor(1.00000e-02 *
#        7.9861)
# v tensor(1.00000e-02 *
#        7.7285)
# v tensor(0.5165)
# v tensor(1.00000e-02 *
#        9.8590)
# v tensor(1.00000e-02 *
#        9.7381)
# v tensor(0.1442)
# v tensor(1.00000e-02 *
#        5.0046)
# v tensor(1.00000e-02 *
#        5.0014)
# v tensor(0.5249)
# v tensor(1.00000e-02 *
#        9.9298)
# v tensor(1.00000e-02 *
#        9.7812)
# v tensor(0.5125)
# v tensor(0.1000)
# v tensor(1.00000e-02 *
#        9.8830)
# v tensor(0.5255)
# v tensor(1.00000e-02 *
#        9.8609)
# v tensor(1.00000e-02 *
#        9.7319)
# v tensor(0.5162)
# v tensor(0.1004)
# v tensor(1.00000e-02 *
#        9.9128)
# v tensor(0.5215)
# v tensor(0.1010)
# v tensor(1.00000e-02 *
#        9.9429)
# v tensor(0.1754)
# v tensor(1.00000e-02 *
#        5.0197)
# v tensor(1.00000e-02 *
#        5.0189)
# v tensor(0.5328)
# v tensor(1.00000e-02 *
#        9.9257)
# v tensor(1.00000e-02 *
#        9.7629)
# v tensor(0.1021)
# v tensor(1.00000e-02 *
#        4.9878)
# v tensor(1.00000e-02 *
#        4.9856)
# v tensor(1.00000e-02 *
#        3.4233)
# v tensor(1.00000e-02 *
#        4.8292)
# v tensor(1.00000e-02 *
#        4.8225)
# v tensor(0.4763)
# v tensor(0.1047)
# v tensor(0.1041)
# v tensor(0.4041)
# v tensor(1.00000e-02 *
#        9.3394)
# v tensor(1.00000e-02 *
#        9.1605)
# v tensor(0.5108)
# v tensor(0.1012)
# v tensor(1.00000e-02 *
#        9.9821)
# v tensor(0.5204)
# v tensor(0.1027)
# v tensor(0.1010)
# v tensor(0.1694)
# v tensor(1.00000e-02 *
#        5.0173)
# v tensor(1.00000e-02 *
#        5.0160)
# v tensor(0.2110)
# v tensor(1.00000e-02 *
#        5.0271)
# v tensor(1.00000e-02 *
#        5.0256)
# v tensor(0.6512)
# v tensor(0.2006)
# v tensor(0.1950)
# v tensor(0.4685)
# v tensor(0.1040)
# v tensor(0.1034)
# v tensor(0.3188)
# v tensor(1.00000e-02 *
#        7.3846)
# v tensor(1.00000e-02 *
#        7.1230)
# v tensor(0.5212)
# v tensor(0.1020)
# v tensor(0.1003)
# v tensor(1.00000e-02 *
#        1.8251)
# v tensor(1.00000e-02 *
#        4.3684)
# v tensor(1.00000e-02 *
#        4.3161)
# v tensor(0.3534)
# v tensor(1.00000e-02 *
#        8.1704)
# v tensor(1.00000e-02 *
#        7.9132)
# v tensor(0.1311)
# v tensor(1.00000e-02 *
#        5.0050)
# v tensor(1.00000e-02 *
#        5.0025)
# v tensor(0.2207)
# v tensor(1.00000e-02 *
#        5.0333)
# v tensor(1.00000e-02 *
#        5.0300)
# v tensor(0.1570)
# v tensor(1.00000e-02 *
#        5.0116)
# v tensor(1.00000e-02 *
#        5.0094)
# v tensor(1.00000e-02 *
#        7.8338)
# v tensor(1.00000e-02 *
#        4.9399)
# v tensor(1.00000e-02 *
#        4.9358)
# v tensor(1.00000e-02 *
#        2.3960)
# v tensor(1.00000e-02 *
#        4.7072)
# v tensor(1.00000e-02 *
#        4.6916)
# v tensor(0.3915)
# v tensor(1.00000e-02 *
#        9.0743)
# v tensor(1.00000e-02 *
#        8.8706)
# v tensor(0.3428)
# v tensor(1.00000e-02 *
#        7.9720)
# v tensor(1.00000e-02 *
#        7.7120)
# v tensor(1.00000e-02 *
#        2.5448)
# v tensor(1.00000e-02 *
#        4.5027)
# v tensor(1.00000e-02 *
#        4.2210)
# v tensor(0.1973)
# v tensor(1.00000e-02 *
#        5.0246)
# v tensor(1.00000e-02 *
#        5.0234)
# v tensor(1.00000e-02 *
#        2.4843)
# v tensor(1.00000e-02 *
#        4.2565)
# v tensor(1.00000e-02 *
#        3.5423)
# v tensor(0.3828)
# v tensor(1.00000e-02 *
#        8.8700)
# v tensor(1.00000e-02 *
#        8.6494)
# v tensor(0.1343)
# v tensor(1.00000e-02 *
#        5.0059)
# v tensor(1.00000e-02 *
#        5.0036)
# v tensor(0.4735)
# v tensor(0.1045)
# v tensor(0.1039)
# v tensor(0.5197)
# v tensor(0.1010)
# v tensor(1.00000e-02 *
#        9.9441)
# v tensor(0.5425)
# v tensor(0.1453)
# v tensor(0.1399)
# v tensor(0.4199)
# v tensor(1.00000e-02 *
#        9.6747)
# v tensor(1.00000e-02 *
#        9.5333)
# v tensor(1.00000e-02 *
#        1.9571)
# v tensor(1.00000e-02 *
#        5.3967)
# v tensor(1.00000e-02 *
#        5.4668)
# v tensor(0.4902)
# v tensor(0.1054)
# v tensor(0.1046)
# v tensor(0.1734)
# v tensor(1.00000e-02 *
#        5.0181)
# v tensor(1.00000e-02 *
#        5.0168)
# v tensor(0.5218)
# v tensor(1.00000e-02 *
#        9.8585)
# v tensor(1.00000e-02 *
#        9.7312)
# v tensor(0.5656)
# v tensor(0.1613)
# v tensor(0.1554)
# v tensor(0.5415)
# v tensor(0.1451)
# v tensor(0.1398)
# v tensor(0.5174)
# v tensor(0.1008)
# v tensor(1.00000e-02 *
#        9.9327)
# v tensor(0.2309)
# v tensor(1.00000e-02 *
#        5.2380)
# v tensor(1.00000e-02 *
#        5.0555)
# v tensor(0.5189)
# v tensor(0.1025)
# v tensor(0.1009)
# v tensor(0.4419)
# v tensor(0.1005)
# v tensor(1.00000e-02 *
#        9.9499)
# v tensor(0.5169)
# v tensor(0.1032)
# v tensor(0.1017)
# v tensor(1.00000e-02 *
#        3.7610)
# v tensor(1.00000e-02 *
#        4.6266)
# v tensor(1.00000e-02 *
#        4.0182)
# v tensor(0.2136)
# v tensor(1.00000e-02 *
#        5.0296)
# v tensor(1.00000e-02 *
#        5.0280)
# v tensor(1.00000e-02 *
#        9.4086)
# v tensor(1.00000e-02 *
#        4.9607)
# v tensor(1.00000e-02 *
#        4.9565)
# v tensor(0.5172)
# v tensor(1.00000e-02 *
#        9.8883)
# v tensor(1.00000e-02 *
#        9.7597)
# v tensor(0.2375)
# v tensor(1.00000e-02 *
#        5.3826)
# v tensor(1.00000e-02 *
#        5.1941)
# v tensor(0.5219)
# v tensor(0.1012)
# v tensor(1.00000e-02 *
#        9.9548)
# v tensor(1.00000e-02 *
#        6.7749)
# v tensor(1.00000e-02 *
#        4.9265)
# v tensor(1.00000e-02 *
#        4.9225)
# v tensor(0.5033)
# v tensor(0.1051)
# v tensor(0.1041)
# v tensor(0.5183)
# v tensor(0.1030)
# v tensor(0.1014)
# v tensor(0.3214)
# v tensor(1.00000e-02 *
#        7.6286)
# v tensor(1.00000e-02 *
#        7.3711)
# v tensor(0.5267)
# v tensor(1.00000e-02 *
#        9.8765)
# v tensor(1.00000e-02 *
#        9.7480)
# v tensor(0.1515)
# v tensor(1.00000e-02 *
#        5.0134)
# v tensor(1.00000e-02 *
#        5.0114)
# v tensor(0.1912)
# v tensor(1.00000e-02 *
#        5.0208)
# v tensor(1.00000e-02 *
#        5.0198)
# v tensor(0.4341)
# v tensor(1.00000e-02 *
#        9.9167)
# v tensor(1.00000e-02 *
#        9.8048)
# v tensor(0.2642)
# v tensor(1.00000e-02 *
#        5.9826)
# v tensor(1.00000e-02 *
#        5.7667)
# v tensor(0.5048)
# v tensor(0.1082)
# v tensor(0.1060)
# v tensor(0.2341)
# v tensor(1.00000e-02 *
#        5.2237)
# v tensor(1.00000e-02 *
#        5.0405)
# v tensor(0.3441)
# v tensor(1.00000e-02 *
#        8.0166)
# v tensor(1.00000e-02 *
#        7.7579)
# v tensor(0.1038)
# v tensor(1.00000e-02 *
#        4.9860)
# v tensor(1.00000e-02 *
#        4.9840)
# v tensor(0.5585)
# v tensor(0.1558)
# v tensor(0.1501)
# v tensor(0.5389)
# v tensor(0.1018)
# v tensor(0.1001)
# v tensor(0.1807)
# v tensor(1.00000e-02 *
#        5.0187)
# v tensor(1.00000e-02 *
#        5.0176)
# v tensor(0.5258)
# v tensor(1.00000e-02 *
#        9.9607)
# v tensor(1.00000e-02 *
#        9.8056)
# v tensor(0.5196)
# v tensor(0.1026)
# v tensor(0.1010)
# v tensor(0.1824)
# v tensor(1.00000e-02 *
#        5.0191)
# v tensor(1.00000e-02 *
#        5.0181)
# v tensor(0.5290)
# v tensor(0.1357)
# v tensor(0.1309)
# v tensor(0.4595)
# v tensor(1.00000e-02 *
#        9.4351)
# v tensor(1.00000e-02 *
#        9.0369)
# v tensor(0.4881)
# v tensor(1.00000e-02 *
#        6.9350)
# v tensor(1.00000e-02 *
#        4.9952)
# v tensor(0.2943)
# v tensor(1.00000e-02 *
#        6.2514)
# v tensor(1.00000e-02 *
#        6.2012)
# v tensor(0.6713)
# v tensor(0.1404)
# v tensor(0.1335)
# v tensor(0.2403)
# v tensor(1.00000e-02 *
#        5.4182)
# v tensor(1.00000e-02 *
#        4.8752)
# v tensor(0.1826)
# v tensor(1.00000e-02 *
#        4.8650)
# v tensor(1.00000e-02 *
#        4.8761)
# v tensor(0.3019)
# v tensor(1.00000e-02 *
#        6.6669)
# v tensor(1.00000e-02 *
#        5.9491)
# v tensor(0.7884)
# v tensor(0.1656)
# v tensor(0.1586)
# v tensor(0.2505)
# v tensor(1.00000e-02 *
#        5.6276)
# v tensor(1.00000e-02 *
#        5.4531)
# v tensor(0.7182)
# v tensor(0.1407)
# v tensor(0.1338)
# v tensor(0.3736)
# v tensor(1.00000e-02 *
#        6.8257)
# v tensor(1.00000e-02 *
#        6.2030)
# v tensor(0.2595)
# v tensor(1.00000e-02 *
#        6.7635)
# v tensor(1.00000e-02 *
#        6.7484)
# v tensor(0.2071)
# v tensor(1.00000e-02 *
#        5.0843)
# v tensor(1.00000e-02 *
#        5.0910)
# v tensor(0.6504)
# v tensor(0.1112)
# v tensor(0.1055)
# v tensor(0.8073)
# v tensor(0.1646)
# v tensor(0.1527)
# v tensor(0.5837)
# v tensor(0.1338)
# v tensor(0.1297)
# v tensor(0.4448)
# v tensor(1.00000e-02 *
#        9.8205)
# v tensor(1.00000e-02 *
#        9.4687)
# v tensor(0.3101)
# v tensor(1.00000e-02 *
#        7.1070)
# v tensor(1.00000e-02 *
#        7.0741)
# v tensor(0.4787)
# v tensor(0.1123)
# v tensor(0.1114)
# v tensor(0.9271)
# v tensor(0.1950)
# v tensor(0.1857)
# v tensor(0.4681)
# v tensor(0.1022)
# v tensor(1.00000e-02 *
#        9.8723)
# v tensor(0.2973)
# v tensor(1.00000e-02 *
#        6.7316)
# v tensor(1.00000e-02 *
#        6.7070)
# v tensor(0.3070)
# v tensor(1.00000e-02 *
#        7.5189)
# v tensor(1.00000e-02 *
#        7.4025)
# v tensor(0.2914)
# v tensor(1.00000e-02 *
#        5.9860)
# v tensor(1.00000e-02 *
#        5.7426)
# v tensor(0.4800)
# v tensor(0.1116)
# v tensor(0.1090)
# v tensor(0.7999)
# v tensor(0.1706)
# v tensor(0.1643)
# v tensor(0.4064)
# v tensor(1.00000e-02 *
#        8.9683)
# v tensor(1.00000e-02 *
#        8.6287)
# v tensor(0.4414)
# v tensor(1.00000e-02 *
#        9.4149)
# v tensor(1.00000e-02 *
#        9.0533)
# v tensor(0.6667)
# v tensor(0.1111)
# v tensor(0.1005)
# v tensor(0.2567)
# v tensor(1.00000e-02 *
#        4.8943)
# v tensor(1.00000e-02 *
#        4.7702)
# v tensor(0.3160)
# v tensor(1.00000e-02 *
#        8.1001)
# v tensor(1.00000e-02 *
#        7.9873)
# v tensor(0.4826)
# v tensor(0.1148)
# v tensor(0.1116)
# v tensor(0.6528)
# v tensor(0.1185)
# v tensor(0.1139)
# v tensor(0.3256)
# v tensor(1.00000e-02 *
#        7.1193)
# v tensor(1.00000e-02 *
#        7.0054)
# v tensor(0.3126)
# v tensor(1.00000e-02 *
#        6.0422)
# v tensor(1.00000e-02 *
#        5.3030)
# v tensor(0.2895)
# v tensor(1.00000e-02 *
#        6.8865)
# v tensor(1.00000e-02 *
#        6.8729)
# v tensor(0.2552)
# v tensor(1.00000e-02 *
#        5.2834)
# v tensor(1.00000e-02 *
#        5.0767)
# v tensor(0.5813)
# v tensor(0.1304)
# v tensor(0.1236)
# v tensor(0.6385)
# v tensor(0.1360)
# v tensor(0.1349)
# v tensor(0.2201)
# v tensor(1.00000e-02 *
#        4.8542)
# v tensor(1.00000e-02 *
#        4.9011)
# v tensor(0.2951)
# v tensor(1.00000e-02 *
#        6.5572)
# v tensor(1.00000e-02 *
#        5.8651)
# v tensor(0.4723)
# v tensor(0.1015)
# v tensor(1.00000e-02 *
#        9.7912)
# v tensor(0.3721)
# v tensor(1.00000e-02 *
#        9.3307)
# v tensor(1.00000e-02 *
#        9.1605)
# v tensor(0.8546)
# v tensor(0.1811)
# v tensor(0.1742)
# v tensor(0.3615)
# v tensor(1.00000e-02 *
#        8.7155)
# v tensor(1.00000e-02 *
#        8.5104)
# v tensor(0.2860)
# v tensor(1.00000e-02 *
#        6.2808)
# v tensor(1.00000e-02 *
#        5.5693)
# v tensor(0.5920)
# v tensor(0.1332)
# v tensor(0.1269)
# v tensor(0.6315)
# v tensor(0.1409)
# v tensor(0.1349)
# v tensor(0.1079)
# v tensor(1.00000e-02 *
#        4.9606)
# v tensor(1.00000e-02 *
#        4.9629)
# v tensor(0.4545)
# v tensor(1.00000e-02 *
#        9.8010)
# v tensor(1.00000e-02 *
#        9.5972)
# v tensor(0.3782)
# v tensor(1.00000e-02 *
#        9.3106)
# v tensor(1.00000e-02 *
#        9.1527)
# v tensor(0.3661)
# v tensor(1.00000e-02 *
#        9.1041)
# v tensor(1.00000e-02 *
#        8.9547)
# v tensor(0.2087)
# v tensor(1.00000e-02 *
#        5.7570)
# v tensor(1.00000e-02 *
#        5.5275)
# v tensor(0.5015)
# v tensor(0.1132)
# v tensor(0.1122)
# v tensor(0.3974)
# v tensor(1.00000e-02 *
#        7.6317)
# v tensor(1.00000e-02 *
#        7.0191)
# v tensor(0.1027)
# v tensor(1.00000e-02 *
#        5.0083)
# v tensor(1.00000e-02 *
#        5.0095)
# v tensor(0.5422)
# v tensor(1.00000e-02 *
#        7.0072)
# v tensor(1.00000e-02 *
#        5.1592)
# v tensor(0.3234)
# v tensor(1.00000e-02 *
#        7.1550)
# v tensor(1.00000e-02 *
#        7.0617)
# v tensor(0.3141)
# v tensor(1.00000e-02 *
#        6.9819)
# v tensor(1.00000e-02 *
#        6.9404)
# v tensor(0.2040)
# v tensor(1.00000e-02 *
#        5.7191)
# v tensor(1.00000e-02 *
#        5.5756)
# v tensor(0.6896)
# v tensor(0.1336)
# v tensor(0.1322)
# v tensor(0.2923)
# v tensor(1.00000e-02 *
#        6.9489)
# v tensor(1.00000e-02 *
#        6.9058)
# v tensor(0.3184)
# v tensor(1.00000e-02 *
#        7.5958)
# v tensor(1.00000e-02 *
#        6.9406)
# v tensor(0.5802)
# v tensor(1.00000e-02 *
#        8.9141)
# v tensor(1.00000e-02 *
#        7.8000)
# v tensor(0.5948)
# v tensor(0.1290)
# v tensor(0.1265)
# v tensor(0.7993)
# v tensor(0.1698)
# v tensor(0.1633)
# v tensor(0.3849)
# v tensor(1.00000e-02 *
#        7.7525)
# v tensor(1.00000e-02 *
#        7.5348)
# v tensor(0.3101)
# v tensor(1.00000e-02 *
#        6.5590)
# v tensor(1.00000e-02 *
#        6.3652)
# v tensor(0.3167)
# v tensor(1.00000e-02 *
#        7.0793)
# v tensor(1.00000e-02 *
#        7.0360)
# v tensor(0.3315)
# v tensor(1.00000e-02 *
#        8.6518)
# v tensor(1.00000e-02 *
#        8.4922)
# v tensor(0.2699)
# v tensor(1.00000e-02 *
#        6.2186)
# v tensor(1.00000e-02 *
#        6.0798)
# v tensor(0.7580)
# v tensor(0.1535)
# v tensor(0.1456)
# v tensor(0.1394)
# v tensor(1.00000e-02 *
#        4.9658)
# v tensor(1.00000e-02 *
#        4.9485)
# v tensor(0.6860)
# v tensor(0.1414)
# v tensor(0.1358)
# v tensor(0.3420)
# v tensor(1.00000e-02 *
#        6.3037)
# v tensor(1.00000e-02 *
#        6.0879)
# v tensor(0.2736)
# v tensor(1.00000e-02 *
#        6.8407)
# v tensor(1.00000e-02 *
#        6.8227)
# v tensor(0.3867)
# v tensor(1.00000e-02 *
#        8.1223)
# v tensor(1.00000e-02 *
#        7.9379)
# v tensor(0.3692)
# v tensor(1.00000e-02 *
#        8.0353)
# v tensor(1.00000e-02 *
#        7.7340)
# v tensor(0.6159)
# v tensor(1.00000e-02 *
#        9.9483)
# v tensor(1.00000e-02 *
#        9.0729)
# v tensor(0.5386)
# v tensor(0.1211)
# v tensor(0.1147)
# v tensor(0.3578)
# v tensor(1.00000e-02 *
#        7.3643)
# v tensor(1.00000e-02 *
#        7.2348)
# v tensor(0.2874)
# v tensor(1.00000e-02 *
#        7.9426)
# v tensor(1.00000e-02 *
#        7.7873)
# v tensor(0.6677)
# v tensor(0.1447)
# v tensor(0.1363)
# v tensor(0.3431)
# v tensor(1.00000e-02 *
#        7.0668)
# v tensor(1.00000e-02 *
#        6.9639)
# v tensor(0.3733)
# v tensor(1.00000e-02 *
#        4.9427)
# v tensor(1.00000e-02 *
#        4.9327)
# v tensor(0.7062)
# v tensor(0.1555)
# v tensor(0.1500)
# v tensor(0.4208)
# v tensor(1.00000e-02 *
#        8.4611)
# v tensor(1.00000e-02 *
#        8.0946)
# v tensor(0.1617)
# v tensor(1.00000e-02 *
#        4.9719)
# v tensor(1.00000e-02 *
#        4.9758)
# v tensor(0.4090)
# v tensor(1.00000e-02 *
#        8.9248)
# v tensor(1.00000e-02 *
#        8.6015)
# v tensor(0.5746)
# v tensor(0.1252)
# v tensor(0.1158)
# v tensor(0.3908)
# v tensor(1.00000e-02 *
#        4.9425)
# v tensor(1.00000e-02 *
#        4.9397)
# v tensor(0.3899)
# v tensor(1.00000e-02 *
#        9.5383)
# v tensor(1.00000e-02 *
#        9.3685)
# v tensor(0.3827)
# v tensor(1.00000e-02 *
#        7.4978)
# v tensor(1.00000e-02 *
#        7.2512)
# v tensor(0.2961)
# v tensor(1.00000e-02 *
#        5.6903)
# v tensor(1.00000e-02 *
#        5.5820)
# v tensor(0.1732)
# v tensor(1.00000e-02 *
#        4.8612)
# v tensor(1.00000e-02 *
#        4.8706)
# v tensor(0.2176)
# v tensor(1.00000e-02 *
#        4.9728)
# v tensor(1.00000e-02 *
#        4.9800)
# v tensor(0.6989)
# v tensor(0.1327)
# v tensor(0.1240)
# v tensor(0.5207)
# v tensor(1.00000e-02 *
#        5.9602)
# v tensor(1.00000e-02 *
#        4.9495)
# v tensor(0.2335)
# v tensor(1.00000e-02 *
#        6.4446)
# v tensor(1.00000e-02 *
#        6.1894)
# v tensor(0.4361)
# v tensor(1.00000e-02 *
#        9.7809)
# v tensor(1.00000e-02 *
#        9.4373)

# %%
np.save('fixpoints_300', Hidden300)

# %%
# preprare initial hidden states for all stimuli  
weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(0)
pca = PCA(weight)
pca.pca(T_duration = 5)
context = pca.game.placefield((9, 5))
pca.Dynamics(Actions = 100 * [4], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
             readout_random = False, open_loop = True, context = context)

# %%
pca = PCA(weight)
pca.pca(T_duration = 5)
color = ['r', 'g', 'b', 'm']
for i, hidden in enumerate(Hidden300):
    plt.figure(0)
    plt.scatter(hidden.data.numpy() @ pca.vect[0], hidden.data.numpy() @ pca.vect[1], color = color[i//100])

# %%
pca = PCA(weight)
pca.pca(T_duration = 5)
color = ['r', 'g', 'b', 'm']
for i, hidden in enumerate(Hidden300):
    plt.figure(0)
    plt.scatter(hidden.data.numpy() @ pca.vect[0], hidden.data.numpy() @ pca.vect[2], color = color[i//100])

# %%
pca = PCA(weight)
pca.pca(T_duration = 5)
color = ['r', 'g', 'b', 'm']
for i, hidden in enumerate(Hidden300):
    plt.figure(0)
    plt.scatter(hidden.data.numpy() @ pca.vect[0], hidden.data.numpy() @ pca.vect[3], color = color[i//100])

# %%
pca = PCA(weight)
pca.pca(T_duration = 5)
color = ['r', 'g', 'b', 'm']
for i, hidden in enumerate(Hidden300):
    plt.figure(0)
    plt.scatter(hidden.data.numpy() @ pca.vect[0], hidden.data.numpy() @ pca.vect[4], color = color[i//100])

# %%
weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(300)
pca = PCA(weight)
pca.pca(T_duration = 5)
context = pca.game.placefield((9, 5))
pca.Dynamics(Actions = 10 * [0], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
             readout_random = False, open_loop = True, context = context)
Hiddens0 = []
for i in range(4):
    for j in range(10):
        Hiddens0.append(pca.Hiddens[i, j, -1])

Hidden_300u = []
Velocity_300u = []
for hidden0 in Hiddens0:
    hidden0 = torch.from_numpy(hidden0).type(torch.FloatTensor)
#     hidden0 = torch.randn(1, 512, requires_grad = True)
    hidden, velocity = findslowpoint(weight, hidden0)
    Hidden_300u.append(hidden)
    Velocity_300u.append(velocity)

# %%
pca = PCA(weight)
pca.pca(T_duration = 5)
color = ['r', 'g', 'b', 'm']
for i, hidden in enumerate(Hidden_300u):
    plt.figure(0)
    plt.scatter(hidden.data.numpy() @ pca.vect[0], hidden.data.numpy() @ pca.vect[1], color = color[i//10])

# %%
# stim color up down left right
for action in [2, 0, 1, 3, 4]:
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(0)
    pca = PCA(weight)
    pca.pca(T_duration = 5)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 5))
    pca.Dynamics(Actions = [action], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
                 readout_random = False, open_loop = True, context = context)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm']
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)  
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            for t in np.arange(29):
                plt.scatter(t, (np.linalg.norm(pca.Hiddens[i][j][t+1] - pca.Hiddens[i][j][t])), color = c)

# %%
for i in range(0, 1):
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(i)
    pca = PCA(weight)
    pca.pca(T_duration = 5)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 5))
    pca.Dynamics(Actions = [0], legend = True, T_total =100, T_stim =20, T_duration = 3, \
                 readout_random = False, dopen_loop = False, context = context, e = 1)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm', 'c']
    plt.figure()
    for i in range(1):
        for j in range(1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)  
ax = subplot(1, 1, 1)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.xticks([0, 20, 50, 100], size = 15)
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
# stim color up down left right
for action in [4]:
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(270)
    pca = PCA(weight)
    pca.pca(T_duration = 5)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 5))
    pca.Dynamics(Actions = [action], legend = True, T_total =200, T_stim =20, T_duration = 3, \
                 readout_random = False, open_loop = True, context = context)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm']
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)  
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            plt.plot(np.linalg.norm(pca.dH[i, j], axis = 1), color = c)

# %% [markdown]
# The slowness dh graph seems predicts the spatial structure at the same time hints ability to learn obstacle tasks with the separation of 4 principle directions

# %%
# stim color up down left right
# action order down up right left
for action in [2, 0, 1, 3, 4]:
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(270)
    pca = PCA(weight)
    pca.pca(T_duration = 5)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 5))
    pca.Dynamics(Actions = [action], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
                 readout_random = False, open_loop = True, context = context)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm']
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)  
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            for t in np.arange(29):
                plt.scatter(t, (np.linalg.norm(pca.Hiddens[i][j][t+1] - pca.Hiddens[i][j][t])), color = c)

# %%
# stim color up down left right
for action in [2, 0, 1, 3, 4]:
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(200)
    pca = PCA(weight)
    pca.pca(T_duration = 5)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 5))
    pca.Dynamics(Actions = [action], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
                 readout_random = False, open_loop = True, context = context)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm']
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)  
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            for t in np.arange(29):
                 plt.scatter(t, (np.linalg.norm(pca.Hiddens[i][j][t+1] - pca.Hiddens[i][j][t])), color = c)

# %%
# action up down left right null
# stim color up down left right
for action in [2, 0, 1, 3, 4]:
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(300)
    pca = PCA(weight)
    pca.pca(T_duration = 5)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 5))
    pca.Dynamics(Actions = [action], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
                 readout_random = False, open_loop = True, context = context)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm']
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)  
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            for t in np.arange(29):
                 plt.scatter(t, (np.linalg.norm(pca.Hiddens[i][j][t+1] - pca.Hiddens[i][j][t])), color = c)

# %%
# stim color up down left right
for action in [2, 0, 1, 3, 4]:
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(399)
    pca = PCA(weight)
    pca.pca(T_duration = 5)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 5))
    pca.Dynamics(Actions = [action], legend = True, T_total = 50, T_stim =20, T_duration = 3, \
                 readout_random = False, open_loop = True, context = context)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm']
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)  
    plt.figure()
    for i in range(4):
        for j in range(0, 1):
            c = colors[i]
            for t in np.arange(29):
                plt.scatter(t, (np.linalg.norm(pca.Hiddens[i][j][t+1] - pca.Hiddens[i][j][t])), color = c)

# %%
for i in range(300, 302):
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(i)
    pca = PCA(weight)
    pca.pca(T_duration = 5)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 6))
    pca.Dynamics(Actions = [0], legend = True, T_total =50, T_stim =20, e = 1, T_duration = 3, \
                 readout_random = False, open_loop = True, context = context)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm', 'c']
    plt.figure()
    for i in range(1):
        for j in range(1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)

# %%
for i in range(300, 302):
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(i)
    pca = PCA(weight)
    pca.pca(T_duration = 5, shuffle = True)
    pca.game.gain = 0.1
    context = pca.game.placefield((9, 6))
    pca.Dynamics(Actions = [0], legend = True, T_total =50, T_stim =20, e = 1, T_duration = 3, \
                 readout_random = False, open_loop = True, context = context)
    # long dynamics for different stimulus
    colors = ['b', 'g', 'r', 'm', 'c']
    plt.figure()
    for i in range(1):
        for j in range(1):
            c = colors[i]
            plt.plot(pca.PCs[i, j], color = c)

# %%
for i in range(240, 242):
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(i)
    Info_A, Info_I, Info_P = Memory(weight, k_action = 1, k_stim = 1, k_internal = 1, epsilon = 1, context_gain =1)
    print (Info_I)
# Out:
# 0.00359258777337 0.111252153752 0.19845988994
# [ 0.20793619  0.14652154  0.11355265  0.0986721   0.08997102  0.08340002
#   0.07902051  0.07094319]
# 0.00528027953828 0.114984945027 0.249586715543
# [ 0.27966282  0.17961043  0.1275874   0.09754212  0.07494862  0.06061726
#   0.05284483  0.04706607]

# %%
for i in range(270, 272):
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(i)
    Info_A, Info_I, Info_P = Memory(weight, k_action = 1, k_stim = 1, k_internal = 1, epsilon = 1, context_gain =1)
    print (Info_I)
# Out:
# 0.00493505710333 0.152222948441 0.202392665923
# [ 0.26879487  0.22103227  0.17590467  0.15035506  0.12497558  0.10606365
#   0.09189658  0.0787609 ]
# 0.00390331959992 0.141510585976 0.201703635868
# [ 0.28059016  0.23068032  0.17510214  0.13389911  0.10428355  0.08201929
#   0.06904923  0.05646089]

# %%
for i in range(300, 302):
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(i)
    Info_A, Info_I, Info_P = Memory(weight, k_action = 1, k_stim = 1, k_internal = 1, epsilon = 1, context_gain =1)
    print (Info_I)
# Out:
# 0.00401941463355 0.143619246206 0.241519813308
# [ 0.28156884  0.23252155  0.17156794  0.13090115  0.10672754  0.0881687
#   0.07412084  0.06337742]
# 0.0045640745585 0.209057559742 0.24842383187
# [ 0.33300248  0.29455858  0.25045958  0.2088597   0.17731414  0.15464258
#   0.13579732  0.1178261 ]

# %%
for i in range(350, 351):
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(i)
    Info_A, Info_I, Info_P = Memory(weight, k_action = 1, k_stim = 1, k_internal = 1, epsilon = 1, context_gain =1)
    print (Info_I)
# Out:
# 0.00423414300718 0.175707821548 0.200672547185
# [ 0.31543965  0.28271846  0.22428782  0.17213538  0.13264326  0.10799478
#   0.09109669  0.07934652]

# %% [markdown]
# ## Decoding

# %%
for trial in [0]: 
    size = 15
    Pretest =  PretrainTest(holes = 0, weight_write =  'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(0, 0))        
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)
    Prec0, prec_matrix0 = Pretest.decode(weight = weight, size_range = [size], size_test = [size], epsilon = 1)
    np.save('Dist{}'.format(trial), prec_matrix0)
# Out:
# clear session data 49 2331635712
# 0 4.184245361398758
# clear session data 49 2335182848
# 1 4.168443244043336
# decode train finish 4.176344302721047

# %%
sns.distplot(1 - prec_matrix0.ravel()/15., color = 'b')
sns.distplot(1 - prec_matrix3.ravel()/15, color = 'r')
plt.xlabel('accuracy')
# Out:
# Text(0.5,0,'accuracy')

# %%
for trial in [39]: 
    size = 15
    Pretest =  PretrainTest(holes = 0, weight_write =  'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(0, 0))        
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)
    Prec, prec_matrix = Pretest.decode(weight = weight, size_range = [size], size_test = [size], epsilon = 1)
    np.save('Dist{}'.format(trial), prec_matrix)
# Out:
# clear session data 49 2330468352
# 0 3.457205551749233
# clear session data 49 2331037696
# 1 3.5111453004038777
# decode train finish 3.4841754260765554

# %%
for trial in [100]: 
    size = 15
    Pretest =  PretrainTest(holes = 0, weight_write =  'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(0, 0))        
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)
    Prec, prec_matrix = Pretest.decode(weight = weight, size_range = [size], size_test = [size], epsilon = 1)
    np.save('Dist{}'.format(trial), prec_matrix)

# %%
plt.matshow(prec_matrix - prec_matrix0)
plt.colorbar()
np.mean(prec_matrix - prec_matrix0)
# Out:
# -1.2583233754344303

# %%
# Not distinguish the context, then train decoder, ** the middle increase of decoding error reflects appearence of context separation**

for trial in [200]: 
    size = 15
    Pretest =  PretrainTest(holes = 0, weight_write =  'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(0, 0))        
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)
    Prec, prec_matrix = Pretest.decode(weight = weight, size_range = [size], size_test = [size], epsilon = 1)
    np.save('Dist{}'.format(trial), prec_matrix)
# Out:
# clear session data 49 2377691136
# 0 3.11454423924
# clear session data 49 2377641984
# 1 3.37589635441
# decode train finish 3.24522029683

# %%
for trial in [300]: 
    size = 15
    Pretest =  PretrainTest(holes = 0, weight_write =  'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(0, 0))        
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)
    Prec3, prec_matrix3 = Pretest.decode(weight = weight, size_range = [size], size_test = [size], epsilon = 1)
    np.save('Dist{}'.format(trial), prec_matrix)

# %%
 np.save('Dist{}'.format(trial), prec_matrix3)

# %%
plt.matshow(prec_matrix3 - prec_matrix)
plt.colorbar()
np.mean(prec_matrix3 - prec_matrix)
# Out:
# 0.061106467439978662

# %%
for trial in [359]: 
    size = 15
    Pretest =  PretrainTest(holes = 0, weight_write =  'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(0, 0))        
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)
    Prec, prec_matrix = Pretest.decode(weight = weight, size_range = [size], size_test = [size], epsilon = 1)
    np.save('Dist{}'.format(trial), prec_matrix)
# Out:
# clear session data 49 2377641984
# 0 2.63301043751
# clear session data 49 2377641984
# 1 3.67791863292
# decode train finish 3.15546453522

# %%
for trial in [399]: 
    size = 15
    Pretest =  PretrainTest(holes = 0, weight_write =  'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial), inputs_type=(0, 0))        
    weight = 'weights_cpu/rnn_1515tanh512_checkpoint{}'.format(trial)
    Prec4, prec_matrix4 = Pretest.decode(weight = weight, size_range = [size], size_test = [size], epsilon = 1)
    np.save('Dist{}'.format(trial), prec_matrix4)
# Out:
# clear session data 49 2335428608
# 0 2.9514679194484486
# clear session data 49 2335428608
# 1 3.23368225181158
# decode train finish 3.0925750856300143

# %%
plt.matshow(prec_matrix4 - prec_matrix)
plt.colorbar()
np.mean(prec_matrix4 - prec_matrix)
# Out:
# 0.079249917670852973

# %% [markdown]
# **If increasing gain of action, then directions will be strongly represented, good for obstacles tasks**

# %% [markdown]
# ### Summary
#
# **0 The strategy is directly reflecting the internal dynamics**
#
# **1 The ability to model the external world lies in richness of internal dynamics, for example the distribution of timescales forms during the pretraining**
#
# **2 To characterize the rich internal timescales , there are 5 features, 1,  the ratio limit cycle/fix point 2,  the mean of relaxation time to fix point 3, the variance of relaxation timescale to fix point  4, the distribution of timescales of limit cycles 5,  The multi-stablity from stimulus**
#
# **3 The performance are : extrapolation performance(small, large),  intrapolation performance(small , middle , large),  learning speed, learning stability,  Try to to connect the 5 features of dynamics to the performance metrix**
#
# **4, Until now ratio limit cycle/fix point during the close loop form seems to indicates best the performance but with noise.**

# %% [markdown]
# **what is the relation between close loop and open loop analysis?**

# %% [markdown]
# longer time, there is no pheonmean associate with multi-stability

# %% [markdown]
# Here with action feedback, dynamics shift to a totally different regime which is around hopf bifurcation, but it is not hugely shaped by the stimulus

# %% [markdown]
# From this graph of PC, we will see that the representation states of trajectory (3,5) and (14,5) are actually qutie close to each other , reflecting symmetry in real space, it is in spirit of predictive decoding, using least number of interal states to play well.

# %% [markdown]
# # Conclusion
# **Internal dynamics rather than decoding performance influences more the performance in uncertain enviroments**
#
# **Consider to think in global loops rather than separated system, thus the coupled dynamical system.  This system, which has its genome on its internal weights, will have quite different different pheno-types from the global loops,  richness of internal dynamics turns into extenable phenotypes which supports behaviours across scales.   The different types of attractors, fix point, limit cycle becomes substrate of strategy in different size rooms.  Thus generalization can be done until certain size, which offers complicate behaviour with a "simple mind"**
#
# **The triangle between decoding, dynamics and navigation should be like: 1, dynamics coded by internal weight is most fundamental, it gives rise to different representations(phenotypes).   2,  The relation between decoding and navigation are reciprocal. not random behaviour gives better enviromental prediction(complement the free energy principle) 2,  we should distinguish internal dynamics and global dynamics**
